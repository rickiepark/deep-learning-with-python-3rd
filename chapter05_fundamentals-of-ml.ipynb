# %% [markdown]
# <a href="https://colab.research.google.com/github/rickiepark/deep-learning-with-python-3rd/blob/main/chapter05_fundamentals-of-ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이 노트북은 <[케라스 창시자에게 배우는 딥러닝 (개정 3판)](https://tensorflow.blog/kerasdl3/)>(길벗, 2026)의 예제 코드를 담고 있습니다.

# %%
# !pip install keras keras-hub --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 49.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.0/230.0 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 31.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.26.0 requires keras-hub==0.26.0, but you have keras-hub 0.31.0 which is incompatible.

# %%
import keras, keras_hub

print(keras.__version__)
print(keras_hub.__version__)
# Out:
# 3.15.1
# 0.31.0

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"이 셀은 {required} 백엔드가 필요합니다. 실행을 위해 노트북 서두에서 KERAS_BACKEND를 "
            f"\"{required}\"로 바꾸고 런타임을 재식한 다음 노트북을 다시 실행하세요."
        )

# %% [markdown]
# ## 머신 러닝의 기본 요소

# %% [markdown]
# ### 일반화: 머신 러닝의 목표

# %% [markdown]
# #### 과소적합과 과대적합

# %% [markdown]
# ##### 잡음 섞인 훈련 데이터

# %% [markdown]
# ##### 불확실한 특성

# %% [markdown]
# ##### 드문 특성과 가짜 상관관계

# %%
from keras.datasets import mnist
import numpy as np

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

train_images_with_noise_channels = np.concatenate(
    [train_images, np.random.random((len(train_images), 784))], axis=1
)

train_images_with_zeros_channels = np.concatenate(
    [train_images, np.zeros((len(train_images), 784))], axis=1
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
import keras
from keras import layers

def get_model():
    model = keras.Sequential(
        [
            layers.Dense(512, activation="relu"),
            layers.Dense(10, activation="softmax"),
        ]
    )
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

model = get_model()
history_noise = model.fit(
    train_images_with_noise_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)

model = get_model()
history_zeros = model.fit(
    train_images_with_zeros_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8687 - loss: 0.4382 - val_accuracy: 0.9212 - val_loss: 0.2765
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9317 - loss: 0.2329 - val_accuracy: 0.9433 - val_loss: 0.1973
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9541 - loss: 0.1559 - val_accuracy: 0.9503 - val_loss: 0.1672
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9684 - loss: 0.1091 - val_accuracy: 0.9555 - val_loss: 0.1519
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9773 - loss: 0.0787 - val_accuracy: 0.9595 - val_loss: 0.1369
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9846 - loss: 0.0541 - val_accuracy: 0.9622 - val_loss: 0.1248
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9896 - loss: 0.0380 - val_accuracy: 0.9595 - val_loss: 0.1362
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - loss: 0.0280 - val_accuracy: 0.9583 - val_loss: 0.1417
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9951 - loss: 0.0202 - val_accuracy: 0.9630 - val_loss: 0.1340
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9963 - loss: 0.0159 - val_accuracy: 0.9605 - val_loss: 0.1457
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9144 - loss: 0.3008 - val_accuracy: 0.9579 - val_loss: 0.1522
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9641 - loss: 0.1241 - val_accuracy: 0.9677 - val_loss: 0.1084
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9761 - loss: 0.0823 - val_accuracy: 0.9722 - val_loss: 0.0943
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9841 - loss: 0.0569 - val_accuracy: 0.9729 - val_loss: 0.0912
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9873 - loss: 0.0439 - val_accuracy: 0.9741 - val_loss: 0.0823
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0322 - val_accuracy: 0.9764 - val_loss: 0.0789
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - loss: 0.0236 - val_accuracy: 0.9772 - val_loss: 0.0769
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9959 - loss: 0.0179 - val_accuracy: 0.9795 - val_loss: 0.0711
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9975 - loss: 0.0124 - val_accuracy: 0.9782 - val_loss: 0.0754
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9982 - loss: 0.0092 - val_accuracy: 0.9772 - val_loss: 0.0829

# %%
import matplotlib.pyplot as plt

val_acc_noise = history_noise.history["val_accuracy"]
val_acc_zeros = history_zeros.history["val_accuracy"]
epochs = range(1, 11)
plt.plot(
    epochs,
    val_acc_noise,
    "b-",
    label="Validation accuracy with noise channels",
)
plt.plot(
    epochs,
    val_acc_zeros,
    "r--",
    label="Validation accuracy with zeros channels",
)
plt.title("Effect of noise channels on validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# #### 딥러닝에서 일반화의 본질

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

random_train_labels = train_labels[:]
np.random.shuffle(random_train_labels)

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images,
    random_train_labels,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.1039 - loss: 2.3161 - val_accuracy: 0.1114 - val_loss: 2.3057
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1157 - loss: 2.2989 - val_accuracy: 0.1035 - val_loss: 2.3077
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1256 - loss: 2.2907 - val_accuracy: 0.1059 - val_loss: 2.3160
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1392 - loss: 2.2783 - val_accuracy: 0.1002 - val_loss: 2.3271
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1525 - loss: 2.2622 - val_accuracy: 0.1023 - val_loss: 2.3317
# Epoch 6/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1659 - loss: 2.2422 - val_accuracy: 0.1032 - val_loss: 2.3478
# Epoch 7/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1790 - loss: 2.2201 - val_accuracy: 0.1038 - val_loss: 2.3622
# Epoch 8/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1966 - loss: 2.1926 - val_accuracy: 0.1024 - val_loss: 2.3748
# Epoch 9/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2119 - loss: 2.1623 - val_accuracy: 0.1012 - val_loss: 2.4008
# Epoch 10/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2289 - loss: 2.1310 - val_accuracy: 0.0987 - val_loss: 2.4244
# Epoch 11/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2419 - loss: 2.0978 - val_accuracy: 0.0993 - val_loss: 2.4411
# Epoch 12/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2610 - loss: 2.0600 - val_accuracy: 0.1018 - val_loss: 2.4795
# Epoch 13/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2775 - loss: 2.0228 - val_accuracy: 0.0997 - val_loss: 2.5069
# Epoch 14/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2952 - loss: 1.9856 - val_accuracy: 0.1005 - val_loss: 2.5370
# Epoch 15/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3131 - loss: 1.9467 - val_accuracy: 0.1012 - val_loss: 2.5689
# Epoch 16/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3297 - loss: 1.9091 - val_accuracy: 0.1012 - val_loss: 2.5919
# Epoch 17/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3438 - loss: 1.8704 - val_accuracy: 0.0996 - val_loss: 2.6292
# Epoch 18/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3606 - loss: 1.8298 - val_accuracy: 0.1002 - val_loss: 2.6583
# Epoch 19/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3783 - loss: 1.7896 - val_accuracy: 0.0990 - val_loss: 2.7076
# Epoch 20/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3928 - loss: 1.7511 - val_accuracy: 0.1022 - val_loss: 2.7510
# Epoch 21/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4094 - loss: 1.7146 - val_accuracy: 0.0991 - val_loss: 2.7891
# Epoch 22/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8582 - loss: 0.4505 - val_accuracy: 0.0996 - val_loss: 6.9976
# Epoch 87/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8618 - loss: 0.4394 - val_accuracy: 0.0989 - val_loss: 7.0944
# Epoch 88/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8633 - loss: 0.4321 - val_accuracy: 0.0967 - val_loss: 7.1184
# Epoch 89/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8671 - loss: 0.4250 - val_accuracy: 0.0986 - val_loss: 7.2422
# Epoch 90/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8690 - loss: 0.4163 - val_accuracy: 0.0973 - val_loss: 7.2866
# Epoch 91/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8719 - loss: 0.4095 - val_accuracy: 0.0979 - val_loss: 7.4110
# Epoch 92/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8759 - loss: 0.3991 - val_accuracy: 0.0955 - val_loss: 7.4632
# Epoch 93/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8771 - loss: 0.3941 - val_accuracy: 0.0974 - val_loss: 7.5143
# Epoch 94/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8799 - loss: 0.3874 - val_accuracy: 0.0966 - val_loss: 7.6317
# Epoch 95/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8824 - loss: 0.3800 - val_accuracy: 0.0988 - val_loss: 7.7024
# Epoch 96/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8840 - loss: 0.3731 - val_accuracy: 0.0985 - val_loss: 7.7857
# Epoch 97/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8867 - loss: 0.3662 - val_accuracy: 0.0968 - val_loss: 7.8488
# Epoch 98/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8892 - loss: 0.3614 - val_accuracy: 0.0992 - val_loss: 7.8857
# Epoch 99/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8918 - loss: 0.3547 - val_accuracy: 0.0976 - val_loss: 8.0608
# Epoch 100/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8924 - loss: 0.3465 - val_accuracy: 0.0969 - val_loss: 8.0752

# %% [markdown]
# ##### 매니폴드 가설

# %% [markdown]
# ##### 일반화의 원천인 보간

# %% [markdown]
# ##### 딥러닝이 작동하는 이유

# %% [markdown]
# ##### 가장 중요한 훈련 데이터

# %% [markdown]
# ### 머신 러닝 모델 평가

# %% [markdown]
# #### 훈련, 검증, 테스트 세트

# %% [markdown]
# ##### 단순 홀드아웃 검증

# %% [markdown]
# ##### K-겹 교차 검증

# %% [markdown]
# ##### 셔플링을 사용한 반복 K-겹 교차 검증

# %% [markdown]
# #### 상식 수준의 기준점 넘기

# %% [markdown]
# #### 모델 평가에 대해 유의할 점

# %% [markdown]
# ### 훈련 성능 향상하기

# %% [markdown]
# #### 경사 하강법의 핵심 파라마터 튜닝하기

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=1.0),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images, train_labels, epochs=10, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3220 - loss: 741.3525 - val_accuracy: 0.1398 - val_loss: 2.3684
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1901 - loss: 4.7062 - val_accuracy: 0.1159 - val_loss: 2.3902
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1861 - loss: 2.4226 - val_accuracy: 0.2073 - val_loss: 2.4339
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1875 - loss: 2.4057 - val_accuracy: 0.2002 - val_loss: 2.1881
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1875 - loss: 2.5198 - val_accuracy: 0.1625 - val_loss: 2.3783
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2030 - loss: 2.3425 - val_accuracy: 0.1973 - val_loss: 2.2029
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2039 - loss: 2.3710 - val_accuracy: 0.2302 - val_loss: 2.3289
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2038 - loss: 2.3688 - val_accuracy: 0.1933 - val_loss: 2.3130
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1901 - loss: 2.3639 - val_accuracy: 0.2251 - val_loss: 2.2363
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2210 - loss: 2.3873 - val_accuracy: 0.2253 - val_loss: 2.1416

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=1e-2),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images, train_labels, epochs=10, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9118 - loss: 0.3429 - val_accuracy: 0.9456 - val_loss: 0.1889
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9773 - loss: 0.0867 - val_accuracy: 0.8811 - val_loss: 0.3221
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9798 - loss: 0.0792 - val_accuracy: 0.8847 - val_loss: 0.3276
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9815 - loss: 0.0727 - val_accuracy: 0.8834 - val_loss: 0.3399
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9848 - loss: 0.0664 - val_accuracy: 0.8811 - val_loss: 0.3512

# %%
original_val_loss = history_original.history["val_loss"]
smaller_model_val_loss = history_smaller_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    smaller_model_val_loss,
    "b-",
    label="Validation loss of smaller model",
)
plt.title("Original model vs. smaller model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(512, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_larger_model = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.7123 - loss: 0.5783 - val_accuracy: 0.8623 - val_loss: 0.3540
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8668 - loss: 0.3192 - val_accuracy: 0.8804 - val_loss: 0.2855
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8983 - loss: 0.2500 - val_accuracy: 0.8892 - val_loss: 0.2722
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9217 - loss: 0.1960 - val_accuracy: 0.8905 - val_loss: 0.2707
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9513 - loss: 0.1392 - val_accuracy: 0.8784 - val_loss: 0.3106
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9626 - loss: 0.1194 - val_accuracy: 0.8828 - val_loss: 0.3364
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9735 - loss: 0.0794 - val_accuracy: 0.8851 - val_loss: 0.3576
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9771 - loss: 0.0806 - val_accuracy: 0.8854 - val_loss: 0.3621
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9976 - loss: 0.0154 - val_accuracy: 0.7870 - val_loss: 1.0225
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9799 - loss: 0.0798 - val_accuracy: 0.8838 - val_loss: 0.4368
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9827 - loss: 0.0717 - val_accuracy: 0.8760 - val_loss: 0.4051
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9998 - loss: 0.0076 - val_accuracy: 0.8825 - val_loss: 0.4723
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9999 - loss: 0.0028 - val_accuracy: 0.8834 - val_loss: 0.5405
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9791 - loss: 0.1075 - val_accuracy: 0.8819 - val_loss: 0.4411
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9999 - loss: 0.0034 - val_accuracy: 0.8851 - val_loss: 0.5015
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8848 - val_loss: 0.5729
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 8.7118e-04 - val_accuracy: 0.8834 - val_loss: 0.6308
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 5.3773e-04 - val_accuracy: 0.8828 - val_loss: 0.6743
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 3.4244e-04 - val_accuracy: 0.8832 - val_loss: 0.6939
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.5394e-04 - val_accuracy: 0.8837 - val_loss: 0.7157

# %%
original_val_loss = history_original.history["val_loss"]
larger_model_val_loss = history_larger_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    larger_model_val_loss,
    "b-",
    label="Validation loss of larger model",
)
plt.title("Original model vs. larger model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %% [markdown]
# ##### 가중치 규제하기

# %%
from keras.regularizers import l2

model = keras.Sequential(
    [
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_l2_reg = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.7592 - loss: 0.6402 - val_accuracy: 0.8640 - val_loss: 0.5186
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8862 - loss: 0.4443 - val_accuracy: 0.8715 - val_loss: 0.4289
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9053 - loss: 0.3617 - val_accuracy: 0.8811 - val_loss: 0.3814
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9187 - loss: 0.3152 - val_accuracy: 0.8833 - val_loss: 0.3634
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9275 - loss: 0.2911 - val_accuracy: 0.8860 - val_loss: 0.3565
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9338 - loss: 0.2734 - val_accuracy: 0.8774 - val_loss: 0.3752
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9413 - loss: 0.2574 - val_accuracy: 0.8846 - val_loss: 0.3586
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9406 - loss: 0.2522 - val_accuracy: 0.8841 - val_loss: 0.3649
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9449 - loss: 0.2429 - val_accuracy: 0.8754 - val_loss: 0.3827
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9483 - loss: 0.2350 - val_accuracy: 0.8821 - val_loss: 0.3657
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9505 - loss: 0.2294 - val_accuracy: 0.8747 - val_loss: 0.3955
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9491 - loss: 0.2282 - val_accuracy: 0.8827 - val_loss: 0.3733
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9539 - loss: 0.2216 - val_accuracy: 0.8791 - val_loss: 0.3838
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9545 - loss: 0.2192 - val_accuracy: 0.8764 - val_loss: 0.3909
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9548 - loss: 0.2178 - val_accuracy: 0.8749 - val_loss: 0.4034
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9571 - loss: 0.2128 - val_accuracy: 0.8788 - val_loss: 0.3903
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9580 - loss: 0.2109 - val_accuracy: 0.8775 - val_loss: 0.3905
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9648 - loss: 0.2009 - val_accuracy: 0.8753 - val_loss: 0.4031
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9593 - loss: 0.2054 - val_accuracy: 0.8753 - val_loss: 0.4059
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9612 - loss: 0.2028 - val_accuracy: 0.8635 - val_loss: 0.4510

# %%
original_val_loss = history_original.history["val_loss"]
l2_val_loss = history_l2_reg.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    l2_val_loss,
    "b-",
    label="Validation loss of L2-regularized model",
)
plt.title(
    "Original model vs. L2-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %%
from keras import regularizers

regularizers.l1(0.001)
regularizers.l1_l2(l1=0.001, l2=0.001)

# %% [markdown]
# ##### 드롭아웃 추가하기

# %%
model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_dropout = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.5953 - loss: 0.6624 - val_accuracy: 0.8207 - val_loss: 0.5988
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7365 - loss: 0.5763 - val_accuracy: 0.8546 - val_loss: 0.4992
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8038 - loss: 0.4989 - val_accuracy: 0.8624 - val_loss: 0.4199
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8432 - loss: 0.4242 - val_accuracy: 0.8779 - val_loss: 0.3545
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8707 - loss: 0.3685 - val_accuracy: 0.8816 - val_loss: 0.3333
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8905 - loss: 0.3191 - val_accuracy: 0.8883 - val_loss: 0.3059
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9063 - loss: 0.2757 - val_accuracy: 0.8875 - val_loss: 0.3066
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9192 - loss: 0.2484 - val_accuracy: 0.8871 - val_loss: 0.2967
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9266 - loss: 0.2222 - val_accuracy: 0.8865 - val_loss: 0.3002
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9348 - loss: 0.1995 - val_accuracy: 0.8798 - val_loss: 0.3065
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9402 - loss: 0.1817 - val_accuracy: 0.8884 - val_loss: 0.3501
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9475 - loss: 0.1657 - val_accuracy: 0.8832 - val_loss: 0.3408
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9521 - loss: 0.1456 - val_accuracy: 0.8861 - val_loss: 0.3810
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9559 - loss: 0.1375 - val_accuracy: 0.8850 - val_loss: 0.3893
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9591 - loss: 0.1219 - val_accuracy: 0.8838 - val_loss: 0.4087
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9617 - loss: 0.1159 - val_accuracy: 0.8847 - val_loss: 0.4953
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9635 - loss: 0.1105 - val_accuracy: 0.8823 - val_loss: 0.4583
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9674 - loss: 0.0987 - val_accuracy: 0.8789 - val_loss: 0.4706
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9675 - loss: 0.0951 - val_accuracy: 0.8791 - val_loss: 0.5197
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9691 - loss: 0.0928 - val_accuracy: 0.8769 - val_loss: 0.5096

# %%
original_val_loss = history_original.history["val_loss"]
dropout_val_loss = history_dropout.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    dropout_val_loss,
    "b-",
    label="Validation loss of dropout-regularized model",
)
plt.title(
    "Original model vs. dropout-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()
