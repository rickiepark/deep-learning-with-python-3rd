# %% [markdown]
# <a href="https://colab.research.google.com/github/rickiepark/deep-learning-with-python-3rd/blob/main/chapter05_fundamentals-of-ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이 노트북은 <[케라스 창시자에게 배우는 딥러닝 (개정 3판)](https://tensorflow.blog/kerasdl3/)>(길벗, 2026)의 예제 코드를 담고 있습니다.

# %%
# !pip install keras keras-hub --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 37.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 37.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.0/230.0 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.26.0 requires keras-hub==0.26.0, but you have keras-hub 0.31.0 which is incompatible.

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"이 셀은 {required} 백엔드가 필요합니다. 실행을 위해 노트북 서두에서 KERAS_BACKEND를 "
            f"\"{required}\"로 바꾸고 런타임을 재식한 다음 노트북을 다시 실행하세요."
        )

# %%
import keras, keras_hub

print(keras.__version__)
print(keras_hub.__version__)
# Out:
# 3.15.1
# 0.31.0

# %% [markdown]
# ## 머신 러닝의 기본 요소

# %% [markdown]
# ### 일반화: 머신 러닝의 목표

# %% [markdown]
# #### 과소적합과 과대적합

# %% [markdown]
# ##### 잡음 섞인 훈련 데이터

# %% [markdown]
# ##### 불확실한 특성

# %% [markdown]
# ##### 드문 특성과 가짜 상관관계

# %%
from keras.datasets import mnist
import numpy as np

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

train_images_with_noise_channels = np.concatenate(
    [train_images, np.random.random((len(train_images), 784))], axis=1
)

train_images_with_zeros_channels = np.concatenate(
    [train_images, np.zeros((len(train_images), 784))], axis=1
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import keras
from keras import layers

def get_model():
    model = keras.Sequential(
        [
            layers.Dense(512, activation="relu"),
            layers.Dense(10, activation="softmax"),
        ]
    )
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

model = get_model()
history_noise = model.fit(
    train_images_with_noise_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)

model = get_model()
history_zeros = model.fit(
    train_images_with_zeros_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8683 - loss: 0.4361 - val_accuracy: 0.9182 - val_loss: 0.2699
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9316 - loss: 0.2282 - val_accuracy: 0.9457 - val_loss: 0.1954
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9548 - loss: 0.1541 - val_accuracy: 0.9523 - val_loss: 0.1605
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9687 - loss: 0.1092 - val_accuracy: 0.9486 - val_loss: 0.1694
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9776 - loss: 0.0785 - val_accuracy: 0.9577 - val_loss: 0.1415
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9840 - loss: 0.0570 - val_accuracy: 0.9503 - val_loss: 0.1643
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9877 - loss: 0.0438 - val_accuracy: 0.9645 - val_loss: 0.1262
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9925 - loss: 0.0282 - val_accuracy: 0.9619 - val_loss: 0.1301
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9947 - loss: 0.0214 - val_accuracy: 0.9636 - val_loss: 0.1370
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9976 - loss: 0.0131 - val_accuracy: 0.9687 - val_loss: 0.1162
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9152 - loss: 0.3004 - val_accuracy: 0.9527 - val_loss: 0.1706
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9642 - loss: 0.1263 - val_accuracy: 0.9652 - val_loss: 0.1163
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9757 - loss: 0.0827 - val_accuracy: 0.9701 - val_loss: 0.0987
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9827 - loss: 0.0589 - val_accuracy: 0.9730 - val_loss: 0.0868
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9874 - loss: 0.0438 - val_accuracy: 0.9770 - val_loss: 0.0780
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9906 - loss: 0.0322 - val_accuracy: 0.9771 - val_loss: 0.0789
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - loss: 0.0240 - val_accuracy: 0.9768 - val_loss: 0.0801
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9951 - loss: 0.0195 - val_accuracy: 0.9779 - val_loss: 0.0788
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9966 - loss: 0.0150 - val_accuracy: 0.9777 - val_loss: 0.0761
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9984 - loss: 0.0092 - val_accuracy: 0.9767 - val_loss: 0.0826

# %%
import matplotlib.pyplot as plt

val_acc_noise = history_noise.history["val_accuracy"]
val_acc_zeros = history_zeros.history["val_accuracy"]
epochs = range(1, 11)
plt.plot(
    epochs,
    val_acc_noise,
    "b-",
    label="Validation accuracy with noise channels",
)
plt.plot(
    epochs,
    val_acc_zeros,
    "r--",
    label="Validation accuracy with zeros channels",
)
plt.title("Effect of noise channels on validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# #### 딥러닝에서 일반화의 본질

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

random_train_labels = train_labels[:]
np.random.shuffle(random_train_labels)

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images,
    random_train_labels,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1027 - loss: 2.3151 - val_accuracy: 0.1072 - val_loss: 2.3051
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1163 - loss: 2.2991 - val_accuracy: 0.1001 - val_loss: 2.3101
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1284 - loss: 2.2904 - val_accuracy: 0.1023 - val_loss: 2.3189
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1392 - loss: 2.2782 - val_accuracy: 0.1024 - val_loss: 2.3318
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1537 - loss: 2.2620 - val_accuracy: 0.1002 - val_loss: 2.3390
# Epoch 6/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1652 - loss: 2.2430 - val_accuracy: 0.0981 - val_loss: 2.3553
# Epoch 7/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1819 - loss: 2.2204 - val_accuracy: 0.0986 - val_loss: 2.3619
# Epoch 8/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1978 - loss: 2.1924 - val_accuracy: 0.0977 - val_loss: 2.3815
# Epoch 9/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2110 - loss: 2.1640 - val_accuracy: 0.0996 - val_loss: 2.4038
# Epoch 10/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2281 - loss: 2.1318 - val_accuracy: 0.0975 - val_loss: 2.4245
# Epoch 11/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2463 - loss: 2.0984 - val_accuracy: 0.0987 - val_loss: 2.4470
# Epoch 12/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2615 - loss: 2.0618 - val_accuracy: 0.1022 - val_loss: 2.4689
# Epoch 13/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2776 - loss: 2.0241 - val_accuracy: 0.0981 - val_loss: 2.5187
# Epoch 14/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2939 - loss: 1.9879 - val_accuracy: 0.1042 - val_loss: 2.5415
# Epoch 15/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3140 - loss: 1.9483 - val_accuracy: 0.1023 - val_loss: 2.5584
# Epoch 16/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3281 - loss: 1.9102 - val_accuracy: 0.1001 - val_loss: 2.6074
# Epoch 17/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3456 - loss: 1.8704 - val_accuracy: 0.1014 - val_loss: 2.6542
# Epoch 18/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3561 - loss: 1.8311 - val_accuracy: 0.1032 - val_loss: 2.6823
# Epoch 19/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3746 - loss: 1.7929 - val_accuracy: 0.1053 - val_loss: 2.7149
# Epoch 20/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.
100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8460 - loss: 0.4876 - val_accuracy: 0.0962 - val_loss: 6.4546
# Epoch 83/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8503 - loss: 0.4776 - val_accuracy: 0.0958 - val_loss: 6.5428
# Epoch 84/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8552 - loss: 0.4667 - val_accuracy: 0.0962 - val_loss: 6.6144
# Epoch 85/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8553 - loss: 0.4598 - val_accuracy: 0.0971 - val_loss: 6.6487
# Epoch 86/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8598 - loss: 0.4510 - val_accuracy: 0.0965 - val_loss: 6.7484
# Epoch 87/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8600 - loss: 0.4452 - val_accuracy: 0.0961 - val_loss: 6.7730
# Epoch 88/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8637 - loss: 0.4356 - val_accuracy: 0.0980 - val_loss: 6.8755
# Epoch 89/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8680 - loss: 0.4263 - val_accuracy: 0.0962 - val_loss: 6.9204
# Epoch 90/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8678 - loss: 0.4187 - val_accuracy: 0.0971 - val_loss: 6.9593
# Epoch 91/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8713 - loss: 0.4126 - val_accuracy: 0.0964 - val_loss: 7.0025
# Epoch 92/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8752 - loss: 0.4037 - val_accuracy: 0.0970 - val_loss: 7.0899
# Epoch 93/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8767 - loss: 0.3968 - val_accuracy: 0.1012 - val_loss: 7.0866
# Epoch 94/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8801 - loss: 0.3895 - val_accuracy: 0.0991 - val_loss: 7.1783
# Epoch 95/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8825 - loss: 0.3813 - val_accuracy: 0.0954 - val_loss: 7.2351
# Epoch 96/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8851 - loss: 0.3754 - val_accuracy: 0.0937 - val_loss: 7.3041
# Epoch 97/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8871 - loss: 0.3695 - val_accuracy: 0.0990 - val_loss: 7.3634
# Epoch 98/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8880 - loss: 0.3611 - val_accuracy: 0.0967 - val_loss: 7.4071
# Epoch 99/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8914 - loss: 0.3552 - val_accuracy: 0.0983 - val_loss: 7.4794
# Epoch 100/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8936 - loss: 0.3483 - val_accuracy: 0.0972 - val_loss: 7.4994

# %% [markdown]
# ##### 매니폴드 가설

# %% [markdown]
# ##### 일반화의 원천인 보간

# %% [markdown]
# ##### 딥러닝이 작동하는 이유

# %% [markdown]
# ##### 가장 중요한 훈련 데이터

# %% [markdown]
# ### 머신 러닝 모델 평가

# %% [markdown]
# #### 훈련, 검증, 테스트 세트

# %% [markdown]
# ##### 단순 홀드아웃 검증

# %% [markdown]
# ##### K-겹 교차 검증

# %% [markdown]
# ##### 셔플링을 사용한 반복 K-겹 교차 검증

# %% [markdown]
# #### 상식 수준의 기준점 넘기

# %% [markdown]
# #### 모델 평가에 대해 유의할 점

# %% [markdown]
# ### 훈련 성능 향상하기

# %% [markdown]
# #### 경사 하강법의 핵심 파라마터 튜닝하기

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=1.0),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images, train_labels, epochs=10, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1000 - loss: 14.4736 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=1e-2),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images, train_labels, epochs=10, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9109 - loss: 0.3782 - val_accuracy: 0.9515 - val_loss: 0.1704
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9652 - loss: 0.1246 - val_accuracy: 0.9654 - val_loss: 0.1412
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9738 - loss: 0.1003 - val_accuracy: 0.9669 - val_loss: 0.1424
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9792 - loss: 0.0830 - val_accuracy: 0.9712 - val_loss: 0.1493
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9821 - loss: 0.0758 - val_accuracy: 0.9714 - val_loss: 0.1625
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9858 - loss: 0.0623 - val_accuracy: 0.9678 - val_loss: 0.2021
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9869 - loss: 0.0573 - val_accuracy: 0.9736 - val_loss: 0.1763
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9887 - loss: 0.0499 - val_accuracy: 0.9683 - val_loss: 0.1937
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0395 - val_accuracy: 0.9746 - val_loss: 0.1877
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9903 - loss: 0.0451 - val_accuracy: 0.9754 - val_loss: 0.1820

# %% [markdown]
# #### 더 나은 구조 가정하기

# %% [markdown]
# #### 모델 용량 늘리기

# %%
model = keras.Sequential([layers.Dense(10, activation="softmax")])
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
history_small_model = model.fit(
    train_images, train_labels, epochs=20, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8368 - loss: 0.6664 - val_accuracy: 0.9037 - val_loss: 0.3585
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9024 - loss: 0.3523 - val_accuracy: 0.9143 - val_loss: 0.3109
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9125 - loss: 0.3174 - val_accuracy: 0.9187 - val_loss: 0.2917
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9157 - loss: 0.3017 - val_accuracy: 0.9223 - val_loss: 0.2826
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9183 - loss: 0.2919 - val_accuracy: 0.9233 - val_loss: 0.2800
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.2854 - val_accuracy: 0.9237 - val_loss: 0.2763
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9214 - loss: 0.2802 - val_accuracy: 0.9261 - val_loss: 0.2723
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9234 - loss: 0.2764 - val_accuracy: 0.9271 - val_loss: 0.2688
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9245 - loss: 0.2733 - val_accuracy: 0.9275 - val_loss: 0.2687
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9247 - loss: 0.2705 - val_accuracy: 0.9282 - val_loss: 0.2670
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9256 - loss: 0.2683 - val_accuracy: 0.9284 - val_loss: 0.2650
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9263 - loss: 0.2663 - val_accuracy: 0.9297 - val_loss: 0.2649
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9271 - loss: 0.2641 - val_accuracy: 0.9296 - val_loss: 0.2653
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9279 - loss: 0.2629 - val_accuracy: 0.9280 - val_loss: 0.2651
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9274 - loss: 0.2613 - val_accuracy: 0.9278 - val_loss: 0.2654
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9283 - loss: 0.2599 - val_accuracy: 0.9297 - val_loss: 0.2637
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9285 - loss: 0.2590 - val_accuracy: 0.9294 - val_loss: 0.2627
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9290 - loss: 0.2579 - val_accuracy: 0.9303 - val_loss: 0.2626
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9293 - loss: 0.2571 - val_accuracy: 0.9292 - val_loss: 0.2653
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9296 - loss: 0.2561 - val_accuracy: 0.9292 - val_loss: 0.2629

# %%
import matplotlib.pyplot as plt

val_loss = history_small_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with insufficient capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(128, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
history_large_model = model.fit(
    train_images,
    train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9028 - loss: 0.3435 - val_accuracy: 0.9530 - val_loss: 0.1679
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9570 - loss: 0.1445 - val_accuracy: 0.9625 - val_loss: 0.1249
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9700 - loss: 0.0978 - val_accuracy: 0.9664 - val_loss: 0.1108
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9775 - loss: 0.0747 - val_accuracy: 0.9719 - val_loss: 0.0958
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9827 - loss: 0.0575 - val_accuracy: 0.9721 - val_loss: 0.0988
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9863 - loss: 0.0455 - val_accuracy: 0.9740 - val_loss: 0.0919
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9882 - loss: 0.0375 - val_accuracy: 0.9733 - val_loss: 0.0972
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9901 - loss: 0.0307 - val_accuracy: 0.9761 - val_loss: 0.0914
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9922 - loss: 0.0244 - val_accuracy: 0.9724 - val_loss: 0.1035
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9933 - loss: 0.0206 - val_accuracy: 0.9763 - val_loss: 0.0982
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9947 - loss: 0.0163 - val_accuracy: 0.9744 - val_loss: 0.1009
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9962 - loss: 0.0131 - val_accuracy: 0.9755 - val_loss: 0.1067
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0102 - val_accuracy: 0.9757 - val_loss: 0.1097
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0097 - val_accuracy: 0.9793 - val_loss: 0.1055
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9977 - loss: 0.0078 - val_accuracy: 0.9768 - val_loss: 0.1131
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9978 - loss: 0.0069 - val_accuracy: 0.9778 - val_loss: 0.1154
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9985 - loss: 0.0052 - val_accuracy: 0.9781 - val_loss: 0.1171
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9987 - loss: 0.0047 - val_accuracy: 0.9756 - val_loss: 0.1242
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9988 - loss: 0.0043 - val_accuracy: 0.9768 - val_loss: 0.1209
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.9768 - val_loss: 0.1290

# %%
val_loss = history_large_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with appropriate capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(2048, activation="relu"),
        layers.Dense(2048, activation="relu"),
        layers.Dense(2048, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
history_very_large_model = model.fit(
    train_images,
    train_labels,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9272 - loss: 0.2581 - val_accuracy: 0.9618 - val_loss: 0.1393
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9696 - loss: 0.1149 - val_accuracy: 0.9684 - val_loss: 0.1320
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9783 - loss: 0.0833 - val_accuracy: 0.9618 - val_loss: 0.1896
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9828 - loss: 0.0704 - val_accuracy: 0.9762 - val_loss: 0.1133
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9862 - loss: 0.0571 - val_accuracy: 0.9788 - val_loss: 0.1187
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9894 - loss: 0.0476 - val_accuracy: 0.9737 - val_loss: 0.1808
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9906 - loss: 0.0411 - val_accuracy: 0.9753 - val_loss: 0.1495
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9919 - loss: 0.0363 - val_accuracy: 0.9780 - val_loss: 0.1468
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9946 - loss: 0.0241 - val_accuracy: 0.9792 - val_loss: 0.1633
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9949 - loss: 0.0238 - val_accuracy: 0.9771 - val_loss: 0.1771
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9961 - loss: 0.0194 - val_accuracy: 0.9754 - val_loss: 0.1853
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9970 - loss: 0.0149 - val_accuracy: 0.9766 - val_loss: 0.1907
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9966 - loss: 0.0165 - val_accuracy: 0.9791 - val_loss: 0.1626
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9970 - loss: 0.0158 - val_accuracy: 0.9821 - val_loss: 0.1542
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9976 - loss: 0.0114 - val_accuracy: 0.9762 - val_loss: 0.2126
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9976 - loss: 0.0125 - val_accuracy: 0.9810 - val_loss: 0.1597
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9987 - loss: 0.0078 - val_accuracy: 0.9816 - val_loss: 0.1610
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9992 - loss: 0.0051 - val_accuracy: 0.9807 - val_loss: 0.1739
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9994 - loss: 0.0035 - val_accuracy: 0.9802 - val_loss: 0.1787
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9992 - loss: 0.0050 - val_accuracy: 0.9807 - val_loss: 0.1787

# %%
val_loss = history_very_large_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with too much capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### 일반화 성능 향상하기

# %% [markdown]
# #### 데이터셋 큐레이션

# %% [markdown]
# #### 특성 공학

# %% [markdown]
# #### 조기 종료 사용하기

# %% [markdown]
# #### 모델 규제하기

# %% [markdown]
# ##### 네트워크 크기 줄이기

# %%
from keras.datasets import imdb

(train_data, train_labels), _ = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.0
    return results

train_data = vectorize_sequences(train_data)

model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_original = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9781 - loss: 0.0878 - val_accuracy: 0.8843 - val_loss: 0.3074
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9807 - loss: 0.0802 - val_accuracy: 0.8814 - val_loss: 0.3224
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9834 - loss: 0.0734 - val_accuracy: 0.8812 - val_loss: 0.3261
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9855 - loss: 0.0670 - val_accuracy: 0.8819 - val_loss: 0.3368

# %%
original_val_loss = history_original.history["val_loss"]
smaller_model_val_loss = history_smaller_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    smaller_model_val_loss,
    "b-",
    label="Validation loss of smaller model",
)
plt.title("Original model vs. smaller model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(512, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_larger_model = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.7452 - loss: 0.5722 - val_accuracy: 0.8736 - val_loss: 0.3460
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8765 - loss: 0.3095 - val_accuracy: 0.8829 - val_loss: 0.2812
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9013 - loss: 0.2443 - val_accuracy: 0.8890 - val_loss: 0.2720
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9329 - loss: 0.1807 - val_accuracy: 0.8593 - val_loss: 0.3373
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9399 - loss: 0.1492 - val_accuracy: 0.8836 - val_loss: 0.3026
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9551 - loss: 0.1198 - val_accuracy: 0.8746 - val_loss: 0.3160
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9732 - loss: 0.0865 - val_accuracy: 0.8876 - val_loss: 0.3330
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9773 - loss: 0.0768 - val_accuracy: 0.8849 - val_loss: 0.3217
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9975 - loss: 0.0172 - val_accuracy: 0.8584 - val_loss: 0.5772
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9831 - loss: 0.0623 - val_accuracy: 0.8845 - val_loss: 0.4415
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9995 - loss: 0.0057 - val_accuracy: 0.7976 - val_loss: 1.0589
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9791 - loss: 0.0833 - val_accuracy: 0.8820 - val_loss: 0.4724
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9998 - loss: 0.0031 - val_accuracy: 0.8839 - val_loss: 0.5548
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9811 - loss: 0.0931 - val_accuracy: 0.8781 - val_loss: 0.4572
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8831 - val_loss: 0.5088
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8840 - val_loss: 0.5869
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 7.8392e-04 - val_accuracy: 0.8832 - val_loss: 0.6408
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 5.0628e-04 - val_accuracy: 0.8830 - val_loss: 0.6692
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 3.3932e-04 - val_accuracy: 0.8827 - val_loss: 0.7106
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 2.5529e-04 - val_accuracy: 0.8832 - val_loss: 0.7208

# %%
original_val_loss = history_original.history["val_loss"]
larger_model_val_loss = history_larger_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    larger_model_val_loss,
    "b-",
    label="Validation loss of larger model",
)
plt.title("Original model vs. larger model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %% [markdown]
# ##### 가중치 규제하기

# %%
from keras.regularizers import l2

model = keras.Sequential(
    [
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_l2_reg = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7848 - loss: 0.6101 - val_accuracy: 0.8581 - val_loss: 0.4876
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8881 - loss: 0.4174 - val_accuracy: 0.8671 - val_loss: 0.4146
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9105 - loss: 0.3410 - val_accuracy: 0.8902 - val_loss: 0.3659
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9222 - loss: 0.3050 - val_accuracy: 0.8880 - val_loss: 0.3562
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9316 - loss: 0.2800 - val_accuracy: 0.8825 - val_loss: 0.3654
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.2661 - val_accuracy: 0.8790 - val_loss: 0.3754
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9429 - loss: 0.2532 - val_accuracy: 0.8861 - val_loss: 0.3626
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9469 - loss: 0.2424 - val_accuracy: 0.8757 - val_loss: 0.3835
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9458 - loss: 0.2376 - val_accuracy: 0.8794 - val_loss: 0.3815
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9504 - loss: 0.2312 - val_accuracy: 0.8754 - val_loss: 0.3928
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9522 - loss: 0.2252 - val_accuracy: 0.8748 - val_loss: 0.3993
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9526 - loss: 0.2251 - val_accuracy: 0.8802 - val_loss: 0.3825
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9561 - loss: 0.2187 - val_accuracy: 0.8667 - val_loss: 0.4257
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9581 - loss: 0.2150 - val_accuracy: 0.8791 - val_loss: 0.3895
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9543 - loss: 0.2154 - val_accuracy: 0.8794 - val_loss: 0.3916
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9600 - loss: 0.2067 - val_accuracy: 0.8508 - val_loss: 0.5079
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9599 - loss: 0.2058 - val_accuracy: 0.8735 - val_loss: 0.4164
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9616 - loss: 0.2028 - val_accuracy: 0.8777 - val_loss: 0.4082
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9603 - loss: 0.2038 - val_accuracy: 0.8777 - val_loss: 0.4075
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9631 - loss: 0.1966 - val_accuracy: 0.8784 - val_loss: 0.4109

# %%
original_val_loss = history_original.history["val_loss"]
l2_val_loss = history_l2_reg.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    l2_val_loss,
    "b-",
    label="Validation loss of L2-regularized model",
)
plt.title(
    "Original model vs. L2-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %%
from keras import regularizers

regularizers.l1(0.001)
regularizers.l1_l2(l1=0.001, l2=0.001)

# %% [markdown]
# ##### 드롭아웃 추가하기

# %%
model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_dropout = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.6307 - loss: 0.6375 - val_accuracy: 0.8202 - val_loss: 0.5289
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7691 - loss: 0.5224 - val_accuracy: 0.8715 - val_loss: 0.4196
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8227 - loss: 0.4404 - val_accuracy: 0.8811 - val_loss: 0.3591
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8627 - loss: 0.3750 - val_accuracy: 0.8890 - val_loss: 0.3035
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8887 - loss: 0.3224 - val_accuracy: 0.8902 - val_loss: 0.2849
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9077 - loss: 0.2775 - val_accuracy: 0.8851 - val_loss: 0.2914
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9151 - loss: 0.2521 - val_accuracy: 0.8896 - val_loss: 0.2818
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9265 - loss: 0.2239 - val_accuracy: 0.8914 - val_loss: 0.2804
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9365 - loss: 0.1939 - val_accuracy: 0.8902 - val_loss: 0.2988
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9423 - loss: 0.1771 - val_accuracy: 0.8881 - val_loss: 0.3051
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9465 - loss: 0.1622 - val_accuracy: 0.8853 - val_loss: 0.3241
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9555 - loss: 0.1448 - val_accuracy: 0.8867 - val_loss: 0.3425
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9587 - loss: 0.1349 - val_accuracy: 0.8862 - val_loss: 0.3855
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9600 - loss: 0.1261 - val_accuracy: 0.8860 - val_loss: 0.3883
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9649 - loss: 0.1126 - val_accuracy: 0.8880 - val_loss: 0.4020
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9677 - loss: 0.1080 - val_accuracy: 0.8870 - val_loss: 0.4239
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9691 - loss: 0.1018 - val_accuracy: 0.8830 - val_loss: 0.4750
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9729 - loss: 0.0910 - val_accuracy: 0.8871 - val_loss: 0.4581
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9753 - loss: 0.0856 - val_accuracy: 0.8850 - val_loss: 0.4858
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9771 - loss: 0.0815 - val_accuracy: 0.8818 - val_loss: 0.5643

# %%
original_val_loss = history_original.history["val_loss"]
dropout_val_loss = history_dropout.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    dropout_val_loss,
    "b-",
    label="Validation loss of dropout-regularized model",
)
plt.title(
    "Original model vs. dropout-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()
