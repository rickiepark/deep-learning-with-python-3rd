# %% [markdown]
# <a href="https://colab.research.google.com/github/rickiepark/deep-learning-with-python-3rd/blob/main/chapter08_image-classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이 노트북은 <[케라스 창시자에게 배우는 딥러닝 (개정 3판)](https://tensorflow.blog/kerasdl3/)>(길벗, 2026)의 예제 코드를 담고 있습니다.

# %%
# !pip install keras keras-hub --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.0/230.0 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.26.0 requires keras-hub==0.26.0, but you have keras-hub 0.31.0 which is incompatible.

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"이 셀은 {required} 백엔드가 필요합니다. 실행을 위해 노트북 서두에서 KERAS_BACKEND를 "
            f"\"{required}\"로 바꾸고 런타임을 재식한 다음 노트북을 다시 실행하세요."
        )

# %%
import keras, keras_hub

print(keras.__version__)
print(keras_hub.__version__)
# Out:
# 3.15.1
# 0.31.0

# %% [markdown]
# ## 이미지 분류

# %% [markdown]
# ### 합성곱 신경망 소개

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)          │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                   │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)      │ (None, 13, 13, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)                 │ (None, 11, 11, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)    │ (None, 5, 5, 128)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)                 │ (None, 3, 3, 256)        │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d          │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense (Dense)                     │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9207 - loss: 0.2563
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9790 - loss: 0.0678
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9861 - loss: 0.0439
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9892 - loss: 0.0348
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9915 - loss: 0.0271

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9912 - loss: 0.0268
# 테스트 정확도: 0.991

# %% [markdown]
# #### 합성곱 연산

# %% [markdown]
# ##### 경계 문제와 패딩 이해하기

# %% [markdown]
# ##### 합성곱 스트라이드 이해하기

# %% [markdown]
# #### 최대 풀링 연산

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary(line_length=80)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)                 │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)                 │ (None, 24, 24, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)                 │ (None, 22, 22, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_1        │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_1 (Dense)                   │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 소규모 데이터셋에서 밑바닥부터 컨브넷 훈련하기

# %% [markdown]
# #### 작은 데이터셋 문제에서 딥러닝의 타당성

# %% [markdown]
# #### 데이터 내려받기

# %%
import kagglehub

kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
download_path = kagglehub.competition_download("dogs-vs-cats")
# Out:
# Downloading to /root/.cache/kagglehub/competitions/dogs-vs-cats.archive...
# 100%|██████████| 812M/812M [00:08<00:00, 100MB/s]
# Extracting files...

# %%
import zipfile

with zipfile.ZipFile(download_path + "/train.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("dogs_vs_cats_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# #### 모델 만들기

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)        │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ rescaling (Rescaling)             │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)                 │ (None, 178, 178, 32)     │           896 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)    │ (None, 89, 89, 32)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)                 │ (None, 87, 87, 64)       │        18,496 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)    │ (None, 43, 43, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)                 │ (None, 41, 41, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)    │ (None, 20, 20, 128)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)                 │ (None, 18, 18, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)    │ (None, 9, 9, 256)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)                │ (None, 7, 7, 512)        │     1,180,160 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_2        │ (None, 512)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_2 (Dense)                   │ (None, 1)                │           513 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 1,569,089 (5.99 MB)
#  Trainable params: 1,569,089 (5.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %% [markdown]
# #### 데이터 전처리

# %%
from keras.utils import image_dataset_from_directory

batch_size = 64
image_size = (180, 180)
train_dataset = image_dataset_from_directory(
    new_base_dir / "train", image_size=image_size, batch_size=batch_size
)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation", image_size=image_size, batch_size=batch_size
)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test", image_size=image_size, batch_size=batch_size
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# ##### 텐서플로 Dataset 객체 이해하기

# %%
import numpy as np
import tensorflow as tf

random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(
    lambda x: tf.reshape(x, (4, 4)),
    num_parallel_calls=8)
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# ##### 모델 훈련하기

# %%
for data_batch, labels_batch in train_dataset:
    print("데이터 배치 크기:", data_batch.shape)
    print("레이블 배치 크기:", labels_batch.shape)
    break
# Out:
# 데이터 배치 크기: (64, 180, 180, 3)
# 레이블 배치 크기: (64,)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 338ms/step - accuracy: 0.5000 - loss: 0.7023 - val_accuracy: 0.5170 - val_loss: 0.6926
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.5225 - loss: 0.6867 - val_accuracy: 0.5360 - val_loss: 0.6842
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.5595 - loss: 0.6688 - val_accuracy: 0.5560 - val_loss: 0.6647
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6295 - loss: 0.6475 - val_accuracy: 0.6430 - val_loss: 0.6210
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - accuracy: 0.6480 - loss: 0.6244 - val_accuracy: 0.5280 - val_loss: 0.7860
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.6415 - loss: 0.6205 - val_accuracy: 0.6040 - val_loss: 0.8157
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.6215 - loss: 0.6429 - val_accuracy: 0.6590 - val_loss: 0.6166
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.6895 - loss: 0.5965 - val_accuracy: 0.7130 - val_loss: 0.5877
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.6930 - loss: 0.5822 - val_accuracy: 0.6740 - val_loss: 0.5904
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.6835 - loss: 0.5908 - val_accuracy: 0.6790 - val_loss: 0.5962
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.6760 - loss: 0.5987 - val_accuracy: 0.6660 - val_loss: 0.6143
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.7085 - loss: 0.5556 - val_accuracy: 0.7130 - val_loss: 0.5715
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.7280 - loss: 0.5525 - val_accuracy: 0.6690 - val_loss: 0.6239
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.7190 - loss: 0.5542 - val_accuracy: 0.7040 - val_loss: 0.5769
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.7470 - loss: 0.5179 - val_accuracy: 0.7380 - val_loss: 0.5332
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.7505 - loss: 0.5179 - val_accuracy: 0.7090 - val_loss: 0.5656
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.7465 - loss: 0.5034 - val_accuracy: 0.7440 - val_loss: 0.5341
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.7585 - loss: 0.5035 - val_accuracy: 0.7370 - val_loss: 0.5448
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.7820 - loss: 0.4677 - val_accuracy: 0.7520 - val_loss: 0.5189
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.7875 - loss: 0.4576 - val_accuracy: 0.7270 - val_loss: 0.5478
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.7860 - loss: 0.4661 - val_accuracy: 0.7560 - val_loss: 0.5286
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.7895 - loss: 0.4426 - val_accuracy: 0.7440 - val_loss: 0.5428
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.8140 - loss: 0.4098 - val_accuracy: 0.7240 - val_loss: 0.6428
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.8275 - loss: 0.3913 - val_accuracy: 0.7670 - val_loss: 0.5159
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.8300 - loss: 0.3865 - val_accuracy: 0.7620 - val_loss: 0.5403
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.8515 - loss: 0.3445 - val_accuracy: 0.7540 - val_loss: 0.5814
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.8305 - loss: 0.3775 - val_accuracy: 0.7650 - val_loss: 0.4988
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.8650 - loss: 0.3111 - val_accuracy: 0.7630 - val_loss: 0.5449
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.8560 - loss: 0.3346 - val_accuracy: 0.7650 - val_loss: 0.5888
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.8940 - loss: 0.2618 - val_accuracy: 0.7200 - val_loss: 0.8251
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9005 - loss: 0.2355 - val_accuracy: 0.7680 - val_loss: 0.5479
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.9090 - loss: 0.2130 - val_accuracy: 0.7930 - val_loss: 0.5512
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - accuracy: 0.8900 - loss: 0.2444 - val_accuracy: 0.7610 - val_loss: 0.7015
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9320 - loss: 0.1753 - val_accuracy: 0.7780 - val_loss: 0.6028
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9400 - loss: 0.1588 - val_accuracy: 0.7900 - val_loss: 0.6119
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9520 - loss: 0.1246 - val_accuracy: 0.7700 - val_loss: 0.6927
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9645 - loss: 0.1058 - val_accuracy: 0.7790 - val_loss: 0.7269
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9700 - loss: 0.0833 - val_accuracy: 0.7840 - val_loss: 0.6660
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9760 - loss: 0.0781 - val_accuracy: 0.7700 - val_loss: 0.8032
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9340 - loss: 0.1740 - val_accuracy: 0.7780 - val_loss: 0.6353
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.9590 - loss: 0.1023 - val_accuracy: 0.7940 - val_loss: 0.6979
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9875 - loss: 0.0477 - val_accuracy: 0.7880 - val_loss: 0.8045
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9895 - loss: 0.0383 - val_accuracy: 0.7960 - val_loss: 0.8062
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9915 - loss: 0.0259 - val_accuracy: 0.7980 - val_loss: 0.7707
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9955 - loss: 0.0208 - val_accuracy: 0.8000 - val_loss: 0.8657
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.9970 - loss: 0.0141 - val_accuracy: 0.7990 - val_loss: 0.8864
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 0.7860 - val_loss: 1.1520
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9955 - loss: 0.0195 - val_accuracy: 0.7930 - val_loss: 0.9455
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9975 - loss: 0.0129 - val_accuracy: 0.8050 - val_loss: 0.9450
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.9960 - loss: 0.0166 - val_accuracy: 0.7960 - val_loss: 0.9454

# %%
import matplotlib.pyplot as plt

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

plt.plot(epochs, accuracy, "r--", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()

plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.7695 - loss: 0.4909
# 테스트 정확도: 0.770

# %% [markdown]
# #### 데이터 증강 사용하기

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
]

def data_augmentation(images, targets):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images, targets

augmented_train_dataset = train_dataset.map(
    data_augmentation, num_parallel_calls=8
)
augmented_train_dataset = augmented_train_dataset.prefetch(tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(10, 10))
for image_batch, _ in train_dataset.take(1):
    image = image_batch[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image, _ = data_augmentation(image, None)
        augmented_image = keras.ops.convert_to_numpy(augmented_image)
        plt.imshow(augmented_image.astype("uint8"))
        plt.axis("off")

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 388ms/step - accuracy: 0.4895 - loss: 0.6956 - val_accuracy: 0.5360 - val_loss: 0.6917
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 425ms/step - accuracy: 0.5230 - loss: 0.6900 - val_accuracy: 0.5380 - val_loss: 0.6896
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 435ms/step - accuracy: 0.5515 - loss: 0.6862 - val_accuracy: 0.5920 - val_loss: 0.6682
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 650ms/step - accuracy: 0.5380 - loss: 0.6835 - val_accuracy: 0.5740 - val_loss: 0.6836
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 436ms/step - accuracy: 0.6025 - loss: 0.6700 - val_accuracy: 0.5890 - val_loss: 0.6682
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 412ms/step - accuracy: 0.6125 - loss: 0.6752 - val_accuracy: 0.6520 - val_loss: 0.6559
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 679ms/step - accuracy: 0.6160 - loss: 0.6548 - val_accuracy: 0.6280 - val_loss: 0.6383
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 640ms/step - accuracy: 0.6430 - loss: 0.6375 - val_accuracy: 0.6120 - val_loss: 0.6538
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 658ms/step - accuracy: 0.6210 - loss: 0.6567 - val_accuracy: 0.6430 - val_loss: 0.6324
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 401ms/step - accuracy: 0.6365 - loss: 0.6417 - val_accuracy: 0.6690 - val_loss: 0.6167
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 440ms/step - accuracy: 0.6595 - loss: 0.6276 - val_accuracy: 0.6430 - val_loss: 0.6210
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 718ms/step - accuracy: 0.6700 - loss: 0.6029 - val_accuracy: 0.6570 - val_loss: 0.6205
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 646ms/step - accuracy: 0.6585 - loss: 0.6099 - val_accuracy: 0.5950 - val_loss: 0.6503
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 612ms/step - accuracy: 0.6650 - loss: 0.6097 - val_accuracy: 0.6960 - val_loss: 0.5788
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 430ms/step - accuracy: 0.6785 - loss: 0.6060 - val_accuracy: 0.6700 - val_loss: 0.6183
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 687ms/step - accuracy: 0.6500 - loss: 0.6252 - val_accuracy: 0.6950 - val_loss: 0.5806
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 418ms/step - accuracy: 0.6925 - loss: 0.5844 - val_accuracy: 0.6870 - val_loss: 0.6270
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 678ms/step - accuracy: 0.6945 - loss: 0.5939 - val_accuracy: 0.7090 - val_loss: 0.5687
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 655ms/step - accuracy: 0.7070 - loss: 0.5774 - val_accuracy: 0.6600 - val_loss: 0.6229
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.7045 - loss: 0.5707 - val_accuracy: 0.7280 - val_loss: 0.5503
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.7195 - loss: 0.5677 - val_accuracy: 0.7150 - val_loss: 0.5644
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 431ms/step - accuracy: 0.7125 - loss: 0.5727 - val_accuracy: 0.7140 - val_loss: 0.5670
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 398ms/step - accuracy: 0.6920 - loss: 0.5770 - val_accuracy: 0.7180 - val_loss: 0.5569
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 677ms/step - accuracy: 0.7210 - loss: 0.5626 - val_accuracy: 0.7130 - val_loss: 0.5562
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 417ms/step - accuracy: 0.7135 - loss: 0.5651 - val_accuracy: 0.7290 - val_loss: 0.5400
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 660ms/step - accuracy: 0.7260 - loss: 0.5418 - val_accuracy: 0.7140 - val_loss: 0.5455
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 674ms/step - accuracy: 0.7195 - loss: 0.5618 - val_accuracy: 0.7060 - val_loss: 0.5629
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 647ms/step - accuracy: 0.7280 - loss: 0.5438 - val_accuracy: 0.7010 - val_loss: 0.5676
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.7345 - loss: 0.5397 - val_accuracy: 0.7010 - val_loss: 0.5699
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 418ms/step - accuracy: 0.7290 - loss: 0.5292 - val_accuracy: 0.6960 - val_loss: 0.6044
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 424ms/step - accuracy: 0.7350 - loss: 0.5439 - val_accuracy: 0.7240 - val_loss: 0.5380
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.7445 - loss: 0.5179 - val_accuracy: 0.6990 - val_loss: 0.6163
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.7310 - loss: 0.5516 - val_accuracy: 0.7320 - val_loss: 0.5353
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 405ms/step - accuracy: 0.7535 - loss: 0.5161 - val_accuracy: 0.7420 - val_loss: 0.5301
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 679ms/step - accuracy: 0.7505 - loss: 0.5208 - val_accuracy: 0.7380 - val_loss: 0.5139
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 647ms/step - accuracy: 0.7385 - loss: 0.5311 - val_accuracy: 0.7420 - val_loss: 0.5254
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 408ms/step - accuracy: 0.7410 - loss: 0.5187 - val_accuracy: 0.7160 - val_loss: 0.5713
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 668ms/step - accuracy: 0.7695 - loss: 0.4945 - val_accuracy: 0.7190 - val_loss: 0.5565
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 427ms/step - accuracy: 0.7630 - loss: 0.4957 - val_accuracy: 0.7000 - val_loss: 0.6186
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 416ms/step - accuracy: 0.7685 - loss: 0.4873 - val_accuracy: 0.7600 - val_loss: 0.4997
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 420ms/step - accuracy: 0.7875 - loss: 0.4721 - val_accuracy: 0.7330 - val_loss: 0.5746
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 663ms/step - accuracy: 0.7750 - loss: 0.4767 - val_accuracy: 0.7310 - val_loss: 0.5775
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 654ms/step - accuracy: 0.7825 - loss: 0.4669 - val_accuracy: 0.7520 - val_loss: 0.4959
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 422ms/step - accuracy: 0.7750 - loss: 0.4740 - val_accuracy: 0.7360 - val_loss: 0.5202
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 651ms/step - accuracy: 0.7925 - loss: 0.4457 - val_accuracy: 0.7590 - val_loss: 0.5076
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 650ms/step - accuracy: 0.7920 - loss: 0.4416 - val_accuracy: 0.7590 - val_loss: 0.4976
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 660ms/step - accuracy: 0.8060 - loss: 0.4292 - val_accuracy: 0.7500 - val_loss: 0.5637
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 657ms/step - accuracy: 0.8055 - loss: 0.4129 - val_accuracy: 0.7900 - val_loss: 0.4863
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 422ms/step - accuracy: 0.8160 - loss: 0.4131 - val_accuracy: 0.7770 - val_loss: 0.4707
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 433ms/step - accuracy: 0.8230 - loss: 0.4055 - val_accuracy: 0.7720 - val_loss: 0.5021
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 660ms/step - accuracy: 0.8335 - loss: 0.3892 - val_accuracy: 0.7750 - val_loss: 0.5690
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.8490 - loss: 0.3628 - val_accuracy: 0.7860 - val_loss: 0.4997
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 430ms/step - accuracy: 0.8160 - loss: 0.4196 - val_accuracy: 0.7860 - val_loss: 0.4610
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 663ms/step - accuracy: 0.8280 - loss: 0.3813 - val_accuracy: 0.7800 - val_loss: 0.4389
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 617ms/step - accuracy: 0.8450 - loss: 0.3522 - val_accuracy: 0.7930 - val_loss: 0.4466
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.8455 - loss: 0.3446 - val_accuracy: 0.8170 - val_loss: 0.4244
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 673ms/step - accuracy: 0.8540 - loss: 0.3452 - val_accuracy: 0.8110 - val_loss: 0.4347
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 677ms/step - accuracy: 0.8510 - loss: 0.3407 - val_accuracy: 0.7960 - val_loss: 0.4355
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.8670 - loss: 0.3148 - val_accuracy: 0.8120 - val_loss: 0.4728
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 396ms/step - accuracy: 0.8500 - loss: 0.3433 - val_accuracy: 0.7990 - val_loss: 0.4441
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 408ms/step - accuracy: 0.8470 - loss: 0.3289 - val_accuracy: 0.8060 - val_loss: 0.4345
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 645ms/step - accuracy: 0.8380 - loss: 0.3790 - val_accuracy: 0.8030 - val_loss: 0.4352
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 406ms/step - accuracy: 0.8465 - loss: 0.3486 - val_accuracy: 0.8220 - val_loss: 0.4094
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 437ms/step - accuracy: 0.8695 - loss: 0.3099 - val_accuracy: 0.8430 - val_loss: 0.4054
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 666ms/step - accuracy: 0.8735 - loss: 0.2940 - val_accuracy: 0.8280 - val_loss: 0.4167
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 389ms/step - accuracy: 0.8670 - loss: 0.3032 - val_accuracy: 0.8070 - val_loss: 0.4752
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 431ms/step - accuracy: 0.8690 - loss: 0.3145 - val_accuracy: 0.8080 - val_loss: 0.4489
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 425ms/step - accuracy: 0.8765 - loss: 0.2935 - val_accuracy: 0.8310 - val_loss: 0.4058
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 645ms/step - accuracy: 0.8850 - loss: 0.2641 - val_accuracy: 0.8330 - val_loss: 0.4381
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 408ms/step - accuracy: 0.8860 - loss: 0.2697 - val_accuracy: 0.8210 - val_loss: 0.4174
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.8820 - loss: 0.2753 - val_accuracy: 0.7690 - val_loss: 0.5569
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 403ms/step - accuracy: 0.8755 - loss: 0.2993 - val_accuracy: 0.8280 - val_loss: 0.4866
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.8765 - loss: 0.2769 - val_accuracy: 0.8400 - val_loss: 0.3915
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 669ms/step - accuracy: 0.8880 - loss: 0.2581 - val_accuracy: 0.8380 - val_loss: 0.3854
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 666ms/step - accuracy: 0.9050 - loss: 0.2368 - val_accuracy: 0.8520 - val_loss: 0.3744
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 666ms/step - accuracy: 0.8830 - loss: 0.2794 - val_accuracy: 0.8280 - val_loss: 0.3931
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 673ms/step - accuracy: 0.9080 - loss: 0.2214 - val_accuracy: 0.8100 - val_loss: 0.4721
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 665ms/step - accuracy: 0.9060 - loss: 0.2302 - val_accuracy: 0.8320 - val_loss: 0.4381
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 414ms/step - accuracy: 0.8985 - loss: 0.2371 - val_accuracy: 0.8080 - val_loss: 0.4946
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 662ms/step - accuracy: 0.8760 - loss: 0.2854 - val_accuracy: 0.8280 - val_loss: 0.4050
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.8975 - loss: 0.2424 - val_accuracy: 0.8420 - val_loss: 0.4435
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 666ms/step - accuracy: 0.9030 - loss: 0.2147 - val_accuracy: 0.8440 - val_loss: 0.4219
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 665ms/step - accuracy: 0.8990 - loss: 0.2461 - val_accuracy: 0.8320 - val_loss: 0.3916
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 668ms/step - accuracy: 0.8980 - loss: 0.2382 - val_accuracy: 0.8380 - val_loss: 0.4428
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 660ms/step - accuracy: 0.9220 - loss: 0.2068 - val_accuracy: 0.8150 - val_loss: 0.6294
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 667ms/step - accuracy: 0.9055 - loss: 0.2258 - val_accuracy: 0.8330 - val_loss: 0.4530
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 676ms/step - accuracy: 0.9035 - loss: 0.2265 - val_accuracy: 0.8630 - val_loss: 0.3878
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 657ms/step - accuracy: 0.9225 - loss: 0.1887 - val_accuracy: 0.8430 - val_loss: 0.4792
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 378ms/step - accuracy: 0.9160 - loss: 0.2028 - val_accuracy: 0.8530 - val_loss: 0.3783
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 408ms/step - accuracy: 0.9120 - loss: 0.1968 - val_accuracy: 0.8620 - val_loss: 0.3854
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.9305 - loss: 0.1711 - val_accuracy: 0.8470 - val_loss: 0.4682
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 665ms/step - accuracy: 0.9225 - loss: 0.1932 - val_accuracy: 0.8580 - val_loss: 0.4027
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 679ms/step - accuracy: 0.9155 - loss: 0.2026 - val_accuracy: 0.8590 - val_loss: 0.3741
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 400ms/step - accuracy: 0.9285 - loss: 0.1764 - val_accuracy: 0.8570 - val_loss: 0.3901
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 664ms/step - accuracy: 0.9075 - loss: 0.2047 - val_accuracy: 0.8600 - val_loss: 0.3963
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.9290 - loss: 0.1720 - val_accuracy: 0.8670 - val_loss: 0.3635
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 431ms/step - accuracy: 0.9285 - loss: 0.1769 - val_accuracy: 0.8620 - val_loss: 0.3765
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 661ms/step - accuracy: 0.9325 - loss: 0.1768 - val_accuracy: 0.8560 - val_loss: 0.4337
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 676ms/step - accuracy: 0.9355 - loss: 0.1656 - val_accuracy: 0.8740 - val_loss: 0.3785
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 418ms/step - accuracy: 0.9350 - loss: 0.1604 - val_accuracy: 0.8700 - val_loss: 0.3494

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8555 - loss: 0.3987
# 테스트 정확도: 0.856

# %% [markdown]
# ### 사전 훈련된 모델 활용하기

# %% [markdown]
# #### 사전 훈련된 모델을 사용한 특성 추출

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset("xception_41_imagenet")
# Out:
# Downloading to /root/.cache/kagglehub/models/keras/xception/keras/xception_41_imagenet/2/config.json...
# 100%|██████████| 1.79k/1.79k [00:00<00:00, 4.89MB/s]
# Downloading to /root/.cache/kagglehub/models/keras/xception/keras/xception_41_imagenet/2/model.weights.h5...
# 100%|██████████| 79.9M/79.9M [00:02<00:00, 34.0MB/s]

# %%
preprocessor = keras_hub.layers.ImageConverter.from_preset(
    "xception_41_imagenet",
    image_size=(180, 180),
)

# %% [markdown]
# ##### 데이터 증강을 사용하지 않는 빠른 특성 추출

# %%
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = preprocessor(images)
        features = conv_base.predict(preprocessed_images, verbose=0)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)

# %%
train_features.shape
# Out:
# (2000, 6, 6, 2048)

# %%
inputs = keras.Input(shape=(6, 6, 2048))
x = layers.GlobalAveragePooling2D()(inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_features,
    train_labels,
    epochs=10,
    validation_data=(val_features, val_labels),
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9730 - loss: 0.0780 - val_accuracy: 0.9850 - val_loss: 0.0411
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9910 - loss: 0.0258 - val_accuracy: 0.9840 - val_loss: 0.0489
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9925 - loss: 0.0135 - val_accuracy: 0.9840 - val_loss: 0.0487
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9965 - loss: 0.0091 - val_accuracy: 0.9870 - val_loss: 0.0487
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0105 - val_accuracy: 0.9810 - val_loss: 0.0767
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9965 - loss: 0.0087 - val_accuracy: 0.9880 - val_loss: 0.0602
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0051 - val_accuracy: 0.9870 - val_loss: 0.0662
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0025 - val_accuracy: 0.9840 - val_loss: 0.0670
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0073 - val_accuracy: 0.9810 - val_loss: 0.0899
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9985 - loss: 0.0035 - val_accuracy: 0.9820 - val_loss: 0.0974

# %%
import matplotlib.pyplot as plt

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features, test_labels)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9830 - loss: 0.0476
# 테스트 정확도: 0.983

# %% [markdown]
# ##### 데이터 증강을 사용한 특성 추출

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset(
    "xception_41_imagenet",
    trainable=False,
)

# %%
conv_base.trainable = True
len(conv_base.trainable_weights)
# Out:
# 154

# %%
conv_base.trainable = False
len(conv_base.trainable_weights)
# Out:
# 0

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = preprocessor(inputs)
x = conv_base(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.9215 - loss: 0.2294 - val_accuracy: 0.9800 - val_loss: 0.0786
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 717ms/step - accuracy: 0.9655 - loss: 0.1234 - val_accuracy: 0.9870 - val_loss: 0.0469
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 698ms/step - accuracy: 0.9690 - loss: 0.0936 - val_accuracy: 0.9750 - val_loss: 0.0901
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 701ms/step - accuracy: 0.9735 - loss: 0.0754 - val_accuracy: 0.9830 - val_loss: 0.0534
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 476ms/step - accuracy: 0.9755 - loss: 0.0631 - val_accuracy: 0.9860 - val_loss: 0.0488
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 472ms/step - accuracy: 0.9850 - loss: 0.0468 - val_accuracy: 0.9880 - val_loss: 0.0459
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 730ms/step - accuracy: 0.9770 - loss: 0.0634 - val_accuracy: 0.9910 - val_loss: 0.0449
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 717ms/step - accuracy: 0.9775 - loss: 0.0544 - val_accuracy: 0.9840 - val_loss: 0.0452
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.9785 - loss: 0.0686 - val_accuracy: 0.9830 - val_loss: 0.0522
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 478ms/step - accuracy: 0.9890 - loss: 0.0272 - val_accuracy: 0.9840 - val_loss: 0.0557
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 719ms/step - accuracy: 0.9765 - loss: 0.0557 - val_accuracy: 0.9800 - val_loss: 0.0722
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 718ms/step - accuracy: 0.9785 - loss: 0.0630 - val_accuracy: 0.9800 - val_loss: 0.0611
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 440ms/step - accuracy: 0.9870 - loss: 0.0364 - val_accuracy: 0.9840 - val_loss: 0.0670
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 705ms/step - accuracy: 0.9830 - loss: 0.0498 - val_accuracy: 0.9850 - val_loss: 0.0569
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 438ms/step - accuracy: 0.9770 - loss: 0.0695 - val_accuracy: 0.9800 - val_loss: 0.0594
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 702ms/step - accuracy: 0.9810 - loss: 0.0488 - val_accuracy: 0.9820 - val_loss: 0.0660
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 694ms/step - accuracy: 0.9875 - loss: 0.0323 - val_accuracy: 0.9800 - val_loss: 0.0588
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 481ms/step - accuracy: 0.9825 - loss: 0.0456 - val_accuracy: 0.9830 - val_loss: 0.0567
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 464ms/step - accuracy: 0.9840 - loss: 0.0438 - val_accuracy: 0.9790 - val_loss: 0.0786
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 701ms/step - accuracy: 0.9840 - loss: 0.0408 - val_accuracy: 0.9830 - val_loss: 0.0600
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 695ms/step - accuracy: 0.9855 - loss: 0.0350 - val_accuracy: 0.9800 - val_loss: 0.0722
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 703ms/step - accuracy: 0.9795 - loss: 0.0555 - val_accuracy: 0.9790 - val_loss: 0.0690
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 486ms/step - accuracy: 0.9805 - loss: 0.0527 - val_accuracy: 0.9850 - val_loss: 0.0490
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 719ms/step - accuracy: 0.9825 - loss: 0.0496 - val_accuracy: 0.9780 - val_loss: 0.0635
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 723ms/step - accuracy: 0.9850 - loss: 0.0408 - val_accuracy: 0.9830 - val_loss: 0.0605
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 705ms/step - accuracy: 0.9795 - loss: 0.0618 - val_accuracy: 0.9830 - val_loss: 0.0514
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 697ms/step - accuracy: 0.9915 - loss: 0.0314 - val_accuracy: 0.9770 - val_loss: 0.0625
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 487ms/step - accuracy: 0.9870 - loss: 0.0360 - val_accuracy: 0.9770 - val_loss: 0.0578
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 453ms/step - accuracy: 0.9885 - loss: 0.0288 - val_accuracy: 0.9830 - val_loss: 0.0478
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 452ms/step - accuracy: 0.9845 - loss: 0.0484 - val_accuracy: 0.9850 - val_loss: 0.0542

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:869: UserWarning: Skipping variable loading for optimizer 'adam_4', because it has 318 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(store)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 296ms/step - accuracy: 0.9815 - loss: 0.0549
# 테스트 정확도: 0.982

# %% [markdown]
# #### 사전 훈련된 모델 미세 튜닝하기

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 733ms/step - accuracy: 0.9855 - loss: 0.0427 - val_accuracy: 0.9850 - val_loss: 0.0475
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 491ms/step - accuracy: 0.9880 - loss: 0.0438 - val_accuracy: 0.9840 - val_loss: 0.0473
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 504ms/step - accuracy: 0.9880 - loss: 0.0293 - val_accuracy: 0.9840 - val_loss: 0.0472
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 447ms/step - accuracy: 0.9865 - loss: 0.0314 - val_accuracy: 0.9840 - val_loss: 0.0473
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 464ms/step - accuracy: 0.9875 - loss: 0.0318 - val_accuracy: 0.9840 - val_loss: 0.0475
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 686ms/step - accuracy: 0.9910 - loss: 0.0260 - val_accuracy: 0.9850 - val_loss: 0.0480
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 724ms/step - accuracy: 0.9930 - loss: 0.0196 - val_accuracy: 0.9840 - val_loss: 0.0486
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 722ms/step - accuracy: 0.9920 - loss: 0.0204 - val_accuracy: 0.9850 - val_loss: 0.0478
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 477ms/step - accuracy: 0.9905 - loss: 0.0270 - val_accuracy: 0.9850 - val_loss: 0.0478
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 474ms/step - accuracy: 0.9885 - loss: 0.0365 - val_accuracy: 0.9850 - val_loss: 0.0482
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 683ms/step - accuracy: 0.9915 - loss: 0.0224 - val_accuracy: 0.9850 - val_loss: 0.0484
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 473ms/step - accuracy: 0.9885 - loss: 0.0306 - val_accuracy: 0.9850 - val_loss: 0.0478
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 721ms/step - accuracy: 0.9935 - loss: 0.0175 - val_accuracy: 0.9850 - val_loss: 0.0475
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 729ms/step - accuracy: 0.9850 - loss: 0.0355 - val_accuracy: 0.9860 - val_loss: 0.0465
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 744ms/step - accuracy: 0.9890 - loss: 0.0344 - val_accuracy: 0.9860 - val_loss: 0.0463
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 719ms/step - accuracy: 0.9900 - loss: 0.0276 - val_accuracy: 0.9860 - val_loss: 0.0459
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 459ms/step - accuracy: 0.9870 - loss: 0.0357 - val_accuracy: 0.9850 - val_loss: 0.0455
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 456ms/step - accuracy: 0.9910 - loss: 0.0256 - val_accuracy: 0.9860 - val_loss: 0.0466
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 475ms/step - accuracy: 0.9905 - loss: 0.0238 - val_accuracy: 0.9870 - val_loss: 0.0468
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 481ms/step - accuracy: 0.9880 - loss: 0.0299 - val_accuracy: 0.9860 - val_loss: 0.0464
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 483ms/step - accuracy: 0.9915 - loss: 0.0212 - val_accuracy: 0.9870 - val_loss: 0.0460
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 720ms/step - accuracy: 0.9900 - loss: 0.0248 - val_accuracy: 0.9860 - val_loss: 0.0466
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 688ms/step - accuracy: 0.9900 - loss: 0.0283 - val_accuracy: 0.9860 - val_loss: 0.0469
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 481ms/step - accuracy: 0.9905 - loss: 0.0265 - val_accuracy: 0.9860 - val_loss: 0.0466
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 722ms/step - accuracy: 0.9895 - loss: 0.0335 - val_accuracy: 0.9860 - val_loss: 0.0467
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 483ms/step - accuracy: 0.9900 - loss: 0.0269 - val_accuracy: 0.9860 - val_loss: 0.0472
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 480ms/step - accuracy: 0.9895 - loss: 0.0246 - val_accuracy: 0.9850 - val_loss: 0.0464
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 719ms/step - accuracy: 0.9900 - loss: 0.0267 - val_accuracy: 0.9860 - val_loss: 0.0459
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 482ms/step - accuracy: 0.9890 - loss: 0.0344 - val_accuracy: 0.9860 - val_loss: 0.0457
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 717ms/step - accuracy: 0.9915 - loss: 0.0252 - val_accuracy: 0.9860 - val_loss: 0.0459

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:869: UserWarning: Skipping variable loading for optimizer 'adam_5', because it has 318 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(store)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 223ms/step - accuracy: 0.9845 - loss: 0.0520
# 테스트 정확도: 0.985
