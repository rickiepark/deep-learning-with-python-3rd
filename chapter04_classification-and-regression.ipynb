# %% [markdown]
# <a href="https://colab.research.google.com/github/rickiepark/deep-learning-with-python-3rd/blob/main/chapter04_classification-and-regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이 노트북은 <[케라스 창시자에게 배우는 딥러닝 (개정 3판)](https://tensorflow.blog/kerasdl3/)>(길벗, 2026)의 예제 코드를 담고 있습니다.

# %%
# !pip install keras keras-hub --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 30.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.0/230.0 kB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 33.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.26.0 requires keras-hub==0.26.0, but you have keras-hub 0.31.0 which is incompatible.

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"이 셀은 {required} 백엔드가 필요합니다. 실행을 위해 노트북 서두에서 KERAS_BACKEND를 "
            f"\"{required}\"로 바꾸고 런타임을 재식한 다음 노트북을 다시 실행하세요."
        )

# %%
import keras, keras_hub

print(keras.__version__)
print(keras_hub.__version__)
# Out:
# 3.15.1
# 0.31.0

# %% [markdown]
# ## 분류와 회귀

# %% [markdown]
# ### 영화 리뷰 분류: 이진 분류 문제

# %% [markdown]
# #### IMDb 데이터셋

# %%
from keras.datasets import imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# np.int64(1)

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
decoded_review[:100]
# Out:
# "? this film was just brilliant casting location scenery story direction everyone's really suited the"

# %% [markdown]
# #### 데이터 준비

# %%
import numpy as np

def multi_hot_encode(sequences, num_classes):
    results = np.zeros((len(sequences), num_classes))
    for i, sequence in enumerate(sequences):
        results[i][sequence] = 1.0
    return results

x_train = multi_hot_encode(train_data, num_classes=10000)
x_test = multi_hot_encode(test_data, num_classes=10000)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = train_labels.astype("float32")
y_test = test_labels.astype("float32")

# %% [markdown]
# #### 모델 만들기

# %%
import keras
from keras import layers

model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)

# %% [markdown]
# #### 훈련 및 검증

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=512,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.7876 - loss: 0.5228 - val_accuracy: 0.8626 - val_loss: 0.3729
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9033 - loss: 0.2794 - val_accuracy: 0.8822 - val_loss: 0.2944
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9353 - loss: 0.1923 - val_accuracy: 0.8883 - val_loss: 0.2781
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9543 - loss: 0.1438 - val_accuracy: 0.8875 - val_loss: 0.2848
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9675 - loss: 0.1121 - val_accuracy: 0.8822 - val_loss: 0.3003
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9791 - loss: 0.0861 - val_accuracy: 0.8831 - val_loss: 0.3205
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9856 - loss: 0.0672 - val_accuracy: 0.8813 - val_loss: 0.3432
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9906 - loss: 0.0522 - val_accuracy: 0.8788 - val_loss: 0.3709
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9941 - loss: 0.0397 - val_accuracy: 0.8752 - val_loss: 0.4027
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9960 - loss: 0.0308 - val_accuracy: 0.8750 - val_loss: 0.4320
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9983 - loss: 0.0240 - val_accuracy: 0.8735 - val_loss: 0.4644
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9995 - loss: 0.0184 - val_accuracy: 0.8727 - val_loss: 0.4913
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9997 - loss: 0.0140 - val_accuracy: 0.8707 - val_loss: 0.5182
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9998 - loss: 0.0111 - val_accuracy: 0.8717 - val_loss: 0.5405
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9999 - loss: 0.0089 - val_accuracy: 0.8700 - val_loss: 0.5639
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9999 - loss: 0.0073 - val_accuracy: 0.8698 - val_loss: 0.5863
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9999 - loss: 0.0061 - val_accuracy: 0.8692 - val_loss: 0.6060
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9999 - loss: 0.0051 - val_accuracy: 0.8686 - val_loss: 0.6247
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9999 - loss: 0.0043 - val_accuracy: 0.8683 - val_loss: 0.6413
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9999 - loss: 0.0037 - val_accuracy: 0.8682 - val_loss: 0.6573

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=512,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9247 - loss: 0.3055 - val_accuracy: 0.9758 - val_loss: 0.0779
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9560 - loss: 0.1322 - val_accuracy: 0.9610 - val_loss: 0.1071
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9757 - loss: 0.0867 - val_accuracy: 0.9528 - val_loss: 0.1234
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9849 - loss: 0.0663 - val_accuracy: 0.9448 - val_loss: 0.1432
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9896 - loss: 0.0519 - val_accuracy: 0.9412 - val_loss: 0.1612
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 0.0408 - val_accuracy: 0.9364 - val_loss: 0.1815
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9952 - loss: 0.0339 - val_accuracy: 0.9340 - val_loss: 0.1978
# Epoch 8/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9966 - loss: 0.0268 - val_accuracy: 0.9322 - val_loss: 0.2151
# Epoch 9/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9978 - loss: 0.0218 - val_accuracy: 0.9288 - val_loss: 0.2365
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9985 - loss: 0.0179 - val_accuracy: 0.9246 - val_loss: 0.2482
# Epoch 11/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9986 - loss: 0.0152 - val_accuracy: 0.9236 - val_loss: 0.2679
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9989 - loss: 0.0126 - val_accuracy: 0.9214 - val_loss: 0.2862
# Epoch 13/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9991 - loss: 0.0106 - val_accuracy: 0.9188 - val_loss: 0.3048
# Epoch 14/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9995 - loss: 0.0087 - val_accuracy: 0.9184 - val_loss: 0.3259
# Epoch 15/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9995 - loss: 0.0072 - val_accuracy: 0.9178 - val_loss: 0.3488
# Epoch 16/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9996 - loss: 0.0060 - val_accuracy: 0.9168 - val_loss: 0.3672
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9997 - loss: 0.0051 - val_accuracy: 0.9168 - val_loss: 0.3842
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9998 - loss: 0.0044 - val_accuracy: 0.9176 - val_loss: 0.4009
# Epoch 19/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9998 - loss: 0.0039 - val_accuracy: 0.9164 - val_loss: 0.4152
# Epoch 20/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9998 - loss: 0.0035 - val_accuracy: 0.9162 - val_loss: 0.4289

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "r--", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("[IMDB] Training and validation loss")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "r--", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("[IMDB] Training and validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.7768 - loss: 0.5161
# Epoch 2/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9088 - loss: 0.2621
# Epoch 3/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9348 - loss: 0.1855
# Epoch 4/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9514 - loss: 0.1455
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8800 - loss: 0.3125

# %%
results
# Out:
# [0.3125271797180176, 0.8799600005149841]

# %% [markdown]
# #### 훈련된 모델로 새로운 데이터에 대해 예측하기

# %%
model.predict(x_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# array([[0.12241305],
#        [0.99997425],
#        [0.74003214],
#        ...,
#        [0.07858299],
#        [0.06336839],
#        [0.6244641 ]], dtype=float32)

# %% [markdown]
# #### 추가 실험

# %% [markdown]
# #### 정리

# %% [markdown]
# ### 뉴스 기사 분류: 다중 분류 문제

# %% [markdown]
# #### 로이터 데이터셋

# %%
from keras.datasets import reuters

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
    num_words=10000
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[10]]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 550378/550378 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_labels[10]
# Out:
# np.int64(3)

# %% [markdown]
# #### 데이터 준비

# %%
x_train = multi_hot_encode(train_data, num_classes=10000)
x_test = multi_hot_encode(test_data, num_classes=10000)

# %%
def one_hot_encode(labels, num_classes=46):
    results = np.zeros((len(labels), num_classes))
    for i, label in enumerate(labels):
        results[i, label] = 1.0
    return results

y_train = one_hot_encode(train_labels)
y_test = one_hot_encode(test_labels)

# %%
from keras.utils import to_categorical

y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# #### 모델 만들기

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)

# %%
top_3_accuracy = keras.metrics.TopKCategoricalAccuracy(
    k=3, name="top_3_accuracy"
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy", top_3_accuracy],
)

# %% [markdown]
# #### 훈련 및 검증

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %%
history = model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=512,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.3300 - loss: 3.3384 - top_3_accuracy: 0.5019 - val_accuracy: 0.5200 - val_loss: 2.6554 - val_top_3_accuracy: 0.6690
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6101 - loss: 2.0551 - top_3_accuracy: 0.7364 - val_accuracy: 0.6580 - val_loss: 1.6176 - val_top_3_accuracy: 0.7680
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7140 - loss: 1.3249 - top_3_accuracy: 0.8180 - val_accuracy: 0.7180 - val_loss: 1.2460 - val_top_3_accuracy: 0.8310
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7796 - loss: 0.9947 - top_3_accuracy: 0.8678 - val_accuracy: 0.7570 - val_loss: 1.1031 - val_top_3_accuracy: 0.8570
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8316 - loss: 0.7774 - top_3_accuracy: 0.9162 - val_accuracy: 0.7830 - val_loss: 1.0252 - val_top_3_accuracy: 0.8750
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8735 - loss: 0.6117 - top_3_accuracy: 0.9469 - val_accuracy: 0.7970 - val_loss: 0.9657 - val_top_3_accuracy: 0.9020
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9007 - loss: 0.4798 - top_3_accuracy: 0.9654 - val_accuracy: 0.8070 - val_loss: 0.9322 - val_top_3_accuracy: 0.9160
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9196 - loss: 0.3784 - top_3_accuracy: 0.9805 - val_accuracy: 0.8210 - val_loss: 0.9131 - val_top_3_accuracy: 0.9150
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9369 - loss: 0.3014 - top_3_accuracy: 0.9868 - val_accuracy: 0.8200 - val_loss: 0.9087 - val_top_3_accuracy: 0.9160
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9424 - loss: 0.2501 - top_3_accuracy: 0.9914 - val_accuracy: 0.8200 - val_loss: 0.9102 - val_top_3_accuracy: 0.9180
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9503 - loss: 0.2069 - top_3_accuracy: 0.9941 - val_accuracy: 0.8210 - val_loss: 0.9297 - val_top_3_accuracy: 0.9200
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9549 - loss: 0.1781 - top_3_accuracy: 0.9956 - val_accuracy: 0.8070 - val_loss: 0.9383 - val_top_3_accuracy: 0.9210
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9544 - loss: 0.1614 - top_3_accuracy: 0.9967 - val_accuracy: 0.8150 - val_loss: 0.9405 - val_top_3_accuracy: 0.9180
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9564 - loss: 0.1404 - top_3_accuracy: 0.9984 - val_accuracy: 0.8170 - val_loss: 0.9736 - val_top_3_accuracy: 0.9210
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9602 - loss: 0.1290 - top_3_accuracy: 0.9982 - val_accuracy: 0.8200 - val_loss: 0.9731 - val_top_3_accuracy: 0.9210
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9598 - loss: 0.1243 - top_3_accuracy: 0.9985 - val_accuracy: 0.8130 - val_loss: 0.9926 - val_top_3_accuracy: 0.9190
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9612 - loss: 0.1137 - top_3_accuracy: 0.9989 - val_accuracy: 0.8160 - val_loss: 1.0145 - val_top_3_accuracy: 0.9150
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9600 - loss: 0.1161 - top_3_accuracy: 0.9986 - val_accuracy: 0.8140 - val_loss: 1.0082 - val_top_3_accuracy: 0.9180
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9605 - loss: 0.1111 - top_3_accuracy: 0.9987 - val_accuracy: 0.8100 - val_loss: 1.0409 - val_top_3_accuracy: 0.9250
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9605 - loss: 0.1023 - top_3_accuracy: 0.9987 - val_accuracy: 0.8210 - val_loss: 1.0239 - val_top_3_accuracy: 0.9230

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["top_3_accuracy"]
val_acc = history.history["val_top_3_accuracy"]
plt.plot(epochs, acc, "r--", label="Training top-3 accuracy")
plt.plot(epochs, val_acc, "b", label="Validation top-3 accuracy")
plt.title("Training and validation top-3 accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Top-3 accuracy")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    x_train,
    y_train,
    epochs=9,
    batch_size=512,
)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.3391 - loss: 3.0560
# Epoch 2/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6323 - loss: 1.8073
# Epoch 3/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7293 - loss: 1.2914
# Epoch 4/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7876 - loss: 0.9918
# Epoch 5/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8336 - loss: 0.7804
# Epoch 6/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8704 - loss: 0.6119
# Epoch 7/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8991 - loss: 0.4785
# Epoch 8/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9211 - loss: 0.3734
# Epoch 9/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9351 - loss: 0.2999
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7907 - loss: 0.9472

# %%
results
# Out:
# [0.9472333788871765, 0.790739119052887]

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels == test_labels_copy)
hits_array.mean()
# Out:
# np.float64(0.18210151380231523)

# %% [markdown]
# #### 새로운 데이터에 대해 예측하기

# %%
predictions = model.predict(x_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# np.float32(1.0)

# %%
np.argmax(predictions[0])
# Out:
# np.int64(3)

# %% [markdown]
# #### 레이블과 손실을 다루는 다른 방법

# %%
y_train = train_labels
y_test = test_labels

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %% [markdown]
# #### 중간층을 충분히 크게 만들어야 하는 이유

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(4, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=128,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.0489 - loss: 3.5655 - val_accuracy: 0.2050 - val_loss: 3.2247
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2903 - loss: 2.6685 - val_accuracy: 0.3020 - val_loss: 2.2749
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5287 - loss: 1.7028 - val_accuracy: 0.6320 - val_loss: 1.5451
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6525 - loss: 1.2850 - val_accuracy: 0.6390 - val_loss: 1.4581
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6615 - loss: 1.1655 - val_accuracy: 0.6420 - val_loss: 1.4292
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6872 - loss: 1.0813 - val_accuracy: 0.6550 - val_loss: 1.4311
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7186 - loss: 1.0093 - val_accuracy: 0.6610 - val_loss: 1.4399
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7380 - loss: 0.9487 - val_accuracy: 0.6640 - val_loss: 1.4475
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7481 - loss: 0.8981 - val_accuracy: 0.6810 - val_loss: 1.4999
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7617 - loss: 0.8544 - val_accuracy: 0.6820 - val_loss: 1.5005
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7741 - loss: 0.8146 - val_accuracy: 0.6910 - val_loss: 1.5290
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7977 - loss: 0.7787 - val_accuracy: 0.6870 - val_loss: 1.5637
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8039 - loss: 0.7442 - val_accuracy: 0.6940 - val_loss: 1.5929
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8079 - loss: 0.7054 - val_accuracy: 0.6950 - val_loss: 1.6349
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8115 - loss: 0.6774 - val_accuracy: 0.6960 - val_loss: 1.6611
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8123 - loss: 0.6600 - val_accuracy: 0.7010 - val_loss: 1.6899
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8122 - loss: 0.6397 - val_accuracy: 0.6980 - val_loss: 1.7248
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8158 - loss: 0.6228 - val_accuracy: 0.6960 - val_loss: 1.7528
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8181 - loss: 0.6063 - val_accuracy: 0.6940 - val_loss: 1.8004
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8168 - loss: 0.5938 - val_accuracy: 0.7010 - val_loss: 1.8329

# %% [markdown]
# #### 추가 실험

# %% [markdown]
# #### 정리

# %% [markdown]
# ### 주택 가격 예측: 회귀 문제

# %% [markdown]
# #### 캘리포니아 주택 가격 데이터셋

# %%
from keras.datasets import california_housing

(train_data, train_targets), (test_data, test_targets) = (
    california_housing.load_data(version="small")
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/california_housing.npz
# 743530/743530 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_data.shape
# Out:
# (480, 8)

# %%
test_data.shape
# Out:
# (120, 8)

# %%
train_targets
# Out:
# array([228400., 132900.,  60000.,  95200., 107000., 122500., 132000.,
#        290100., 257800., 390100., 220800., 284900.,  97500., 415300.,
#         84200., 185600., 216700., 233100., 127000., 182300.,  92300.,
#         90700., 102100., 112500., 350700., 156500., 220700., 147400.,
#        216700., 275000., 198200., 119100., 289500., 152500., 125000.,
#        104500.,  93800.,  89300., 452600., 128600., 311500.,  90000.,
#        218200., 131300.,  67500., 139400., 500001., 182600., 111300.,
#        112500., 134700.,  71300., 207400., 331400., 107900.,  87500.,
#        342200.,  87100., 314700., 368600., 211600., 338900., 366100.,
#        164300.,  91700., 261400., 218500., 155400., 273700.,  81800.,
#        138800.,  99700., 156300., 140600., 152700., 108900., 351200.,
#        126000., 137500., 196900., 240000., 172800., 254200.,  97500.,
#        182700., 162500.,  86100., 226700., 412500., 165900., 327100.,
#        162500., 188800., 183800.,  90600., 372000., 275000., 151800.,
#        125000., 129100., 176000., 124700., 215300., 198100., 206300.,
#        122300., 277800., 335200., 274700., 132600., 143900., 299200.,
#        160000., 210200., 171400., 138800., 203300., 143800.,  85800.,
#         75000., 112200., 340400., 105500., 208100., 270900.,  85700.,
#         81300., 352100., 285800., 270600., 216700., 270100., 374400.,
#        192100., 241700., 341300., 150000., 126300., 118800., 500001.,
#         95200., 173700., 175000., 113900., 335000., 100000., 235600.,
#        109700., 210200.,  81400., 286600., 201300., 142300., 102300.,
#        184400.,  98300., 295200., 247100., 107500., 104900.,  79700.,
#        112500., 318200.,  83400., 269500., 227900., 287500., 261100.,
#        166900., 144000., 245500., 101600., 471600., 240700., 137500.,
#         75000.,  80800., 257300., 162900., 292000., 323500., 126900.,
#        351800., 269700., 212900., 259600., 268500., 182300., 197900.,
#        213500., 107600., 231600., 335300., 257400., 100000., 206200.,
#        119400., 118100.,  92500., 158700., 289900., 101400., 125000.,
#         91400., 500001., 500001., 275700., 457800., 239800., 250000.,
#        191700., 130000., 156900., 118800.,  88800., 153100., 231000.,
#        430500., 333300., 141900., 140000., 209400., 270900., 225000.,
#        229100., 150000., 164700.,  82800., 135800., 116700., 405400.,
#        231600.,  89500., 276800., 248600., 195800.,  98200., 319300.,
#        241700., 229800., 306300., 118000., 227700., 128800., 344000.,
#        120000., 110400., 335600., 109400., 161900., 135300., 142500.,
#        347600., 391800.,  82400., 332500., 336800., 109500., 391100.,
#         84700., 252900., 200000., 164300., 187500., 392600., 417500.,
#        263400., 313400., 115400.,  76100., 253600., 265400., 218800.,
#        116100., 169300., 114800., 358800., 302100., 143800., 446200.,
#        456300., 293000., 142600., 137500., 157300., 229300., 102200.,
#        169900., 243100.,  86500., 111100., 246200., 208800., 248500.,
#        295200., 500001., 164400., 365900., 296400., 376900., 242800.,
#         91800., 129500., 130600., 220900., 250000., 263900.,  72500.,
#        234100., 144800., 150000.,  70000.,  90500., 105500., 218400.,
#        282100., 147500., 224200., 120100., 104200.,  97200., 112500.,
#         94800., 273000., 159800., 225000.,  96200., 327600., 111900.,
#        266700., 333000., 375400., 350000., 103900., 243800.,  87100.,
#        141700., 366700.,  80000., 174200., 106300., 102000.,  88900.,
#        348700., 132500., 272900., 292300., 231800., 162500., 187500.,
#        352400., 384600., 153600., 240900., 500001., 189600., 151000.,
#        163500., 229200.,  98700., 138800., 136700., 398600., 254900.,
#        137000., 146900., 371300., 220800., 346800., 341600., 199600.,
#        140600., 342200., 137500., 411500., 125000.,  72000.,  83500.,
#        357300., 187500., 410300., 112500., 273800., 179300., 143400.,
#        121600., 177500., 252800., 287500., 271400., 121400., 131900.,
#        329800.,  85000., 127900., 155500., 172700., 113300., 125000.,
#        252500., 102400., 136700., 221300., 191400.,  82000., 218500.,
#        227000., 144800., 500001., 232500., 243400., 259400., 137500.,
#        337300., 179200., 102800., 207900., 362900., 350000.,  73500.,
#        371100., 182700., 389500., 140600.,  87500., 142900., 196400.,
#        126600., 123500., 311100., 159200.,  95000.,  81800., 253500.,
#        215700., 171900.,  85300.,  80600.,  89300.,  84400.,  75000.,
#        228100.,  95500., 187100.,  94800., 224100., 239600., 115000.,
#        353900., 256100., 335700., 291700., 206300., 119400., 350000.,
#        287300., 191300.,  93800., 175000., 500001., 179300., 118800.,
#        206800., 179900.,  80300., 195500., 147900., 483300., 268800.,
#        158400.,  94300.,  97300., 275400., 248900., 273400., 259300.,
#         75700., 336700., 140500., 217100.], dtype=float32)

# %% [markdown]
# #### 데이터 준비

# %%
mean = train_data.mean(axis=0)
std = train_data.std(axis=0)
x_train = (train_data - mean) / std
x_test = (test_data - mean) / std

# %%
y_train = train_targets / 100000
y_test = test_targets / 100000

# %% [markdown]
# #### 모델 만들기

# %%
def get_model():
    model = keras.Sequential(
        [
            layers.Dense(64, activation="relu"),
            layers.Dense(64, activation="relu"),
            layers.Dense(1),
        ]
    )
    model.compile(
        optimizer="adam",
        loss="mean_squared_error",
        metrics=["mean_absolute_error"],
    )
    return model

# %% [markdown]
# #### 훈련 및 K-겹 교차 검증

# %%
k = 4
num_val_samples = len(x_train) // k
num_epochs = 50
all_scores = []
for i in range(k):
    print(f"#{i + 1}번째 폴드 처리 중")
    fold_x_val = x_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_y_val = y_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_x_train = np.concatenate(
        [x_train[: i * num_val_samples], x_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    fold_y_train = np.concatenate(
        [y_train[: i * num_val_samples], y_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    model = get_model()
    model.fit(
        fold_x_train,
        fold_y_train,
        epochs=num_epochs,
        batch_size=16,
        verbose=0,
    )
    scores = model.evaluate(fold_x_val, fold_y_val, verbose=0)
    val_loss, val_mae = scores
    all_scores.append(val_mae)
# Out:
# #1번째 폴드 처리 중
# #2번째 폴드 처리 중
# #3번째 폴드 처리 중
# #4번째 폴드 처리 중

# %%
[round(value, 3) for value in all_scores]
# Out:
# [0.274, 0.298, 0.24, 0.312]

# %%
round(np.mean(all_scores), 3)
# Out:
# np.float64(0.281)

# %%
k = 4
num_val_samples = len(x_train) // k
num_epochs = 200
all_mae_histories = []
for i in range(k):
    print(f"#{i + 1}번째 폴드 처리 중")
    fold_x_val = x_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_y_val = y_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_x_train = np.concatenate(
        [x_train[: i * num_val_samples], x_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    fold_y_train = np.concatenate(
        [y_train[: i * num_val_samples], y_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    model = get_model()
    history = model.fit(
        fold_x_train,
        fold_y_train,
        validation_data=(fold_x_val, fold_y_val),
        epochs=num_epochs,
        batch_size=16,
        verbose=0,
    )
    mae_history = history.history["val_mean_absolute_error"]
    all_mae_histories.append(mae_history)
# Out:
# #1번째 폴드 처리 중
# #2번째 폴드 처리 중
# #3번째 폴드 처리 중
# #4번째 폴드 처리 중

# %%
average_mae_history = [
    np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)
]

# %%
epochs = range(1, len(average_mae_history) + 1)
plt.plot(epochs, average_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %%
truncated_mae_history = average_mae_history[10:]
epochs = range(10, len(truncated_mae_history) + 10)
plt.plot(epochs, truncated_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %%
model = get_model()
model.fit(x_train, y_train, epochs=130, batch_size=16, verbose=0)
test_mean_squared_error, test_mean_absolute_error = model.evaluate(
    x_test, y_test
)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2981 - mean_absolute_error: 0.3148

# %%
round(test_mean_absolute_error, 3)
# Out:
# 0.315

# %% [markdown]
# #### 새로운 데이터에 대해 예측하기

# %%
predictions = model.predict(x_test)
predictions[0]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# array([2.5341425], dtype=float32)

# %% [markdown]
# #### 정리
