# %% [markdown]
# <a href="https://colab.research.google.com/github/rickiepark/deep-learning-with-python-3rd/blob/main/chapter04_classification-and-regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이 노트북은 <[케라스 창시자에게 배우는 딥러닝 (개정 3판)](https://tensorflow.blog/kerasdl3/)>(길벗, 2026)의 예제 코드를 담고 있습니다.

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import keras, keras_hub

print(keras.__version__)
print(keras_hub.__version__)
# Out:
# 3.15.1
# 0.31.0

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"이 셀은 {required} 백엔드가 필요합니다. 실행을 위해 노트북 서두에서 KERAS_BACKEND를 "
            f"\"{required}\"로 바꾸고 런타임을 재식한 다음 노트북을 다시 실행하세요."
        )

# %% [markdown]
# ## 분류와 회귀

# %% [markdown]
# ### 영화 리뷰 분류: 이진 분류 문제

# %% [markdown]
# #### IMDb 데이터셋

# %%
from keras.datasets import imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000
)

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# np.int64(1)

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]]
)

# %%
decoded_review[:100]
# Out:
# "? this film was just brilliant casting location scenery story direction everyone's really suited the"

# %% [markdown]
# #### 데이터 준비

# %%
import numpy as np

def multi_hot_encode(sequences, num_classes):
    results = np.zeros((len(sequences), num_classes))
    for i, sequence in enumerate(sequences):
        results[i][sequence] = 1.0
    return results

x_train = multi_hot_encode(train_data, num_classes=10000)
x_test = multi_hot_encode(test_data, num_classes=10000)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = train_labels.astype("float32")
y_test = test_labels.astype("float32")

# %% [markdown]
# #### 모델 만들기

# %%
import keras
from keras import layers

model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)

# %% [markdown]
# #### 훈련 및 검증

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=512,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.7615 - loss: 0.5487 - val_accuracy: 0.8580 - val_loss: 0.4080
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8991 - loss: 0.3098 - val_accuracy: 0.8884 - val_loss: 0.3004
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9343 - loss: 0.2094 - val_accuracy: 0.8884 - val_loss: 0.2771
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9539 - loss: 0.1537 - val_accuracy: 0.8868 - val_loss: 0.2797
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9673 - loss: 0.1159 - val_accuracy: 0.8853 - val_loss: 0.2955
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9793 - loss: 0.0874 - val_accuracy: 0.8819 - val_loss: 0.3160
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9871 - loss: 0.0652 - val_accuracy: 0.8784 - val_loss: 0.3419
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9923 - loss: 0.0487 - val_accuracy: 0.8753 - val_loss: 0.3732
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9953 - loss: 0.0364 - val_accuracy: 0.8748 - val_loss: 0.3997
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9977 - loss: 0.0265 - val_accuracy: 0.8733 - val_loss: 0.4277
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9990 - loss: 0.0196 - val_accuracy: 0.8731 - val_loss: 0.4562
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9996 - loss: 0.0147 - val_accuracy: 0.8717 - val_loss: 0.4854
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9997 - loss: 0.0114 - val_accuracy: 0.8703 - val_loss: 0.5101
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9998 - loss: 0.0089 - val_accuracy: 0.8696 - val_loss: 0.5320
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9999 - loss: 0.0071 - val_accuracy: 0.8694 - val_loss: 0.5518
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9999 - loss: 0.0059 - val_accuracy: 0.8691 - val_loss: 0.5726
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9999 - loss: 0.0049 - val_accuracy: 0.8683 - val_loss: 0.5919
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9999 - loss: 0.0042 - val_accuracy: 0.8672 - val_loss: 0.6121
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9999 - loss: 0.0036 - val_accuracy: 0.8675 - val_loss: 0.6296
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9999 - loss: 0.0031 - val_accuracy: 0.8674 - val_loss: 0.6457

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=512,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9280 - loss: 0.2785 - val_accuracy: 0.9708 - val_loss: 0.0892
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9604 - loss: 0.1222 - val_accuracy: 0.9630 - val_loss: 0.1050
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9765 - loss: 0.0810 - val_accuracy: 0.9552 - val_loss: 0.1223
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9866 - loss: 0.0568 - val_accuracy: 0.9504 - val_loss: 0.1303
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9919 - loss: 0.0407 - val_accuracy: 0.9504 - val_loss: 0.1421
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9956 - loss: 0.0284 - val_accuracy: 0.9484 - val_loss: 0.1536
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9975 - loss: 0.0211 - val_accuracy: 0.9460 - val_loss: 0.1668
# Epoch 8/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9981 - loss: 0.0168 - val_accuracy: 0.9430 - val_loss: 0.1816
# Epoch 9/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9988 - loss: 0.0140 - val_accuracy: 0.9422 - val_loss: 0.1925
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9991 - loss: 0.0109 - val_accuracy: 0.9394 - val_loss: 0.2104
# Epoch 11/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9994 - loss: 0.0095 - val_accuracy: 0.9392 - val_loss: 0.2143
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9995 - loss: 0.0072 - val_accuracy: 0.9396 - val_loss: 0.2248
# Epoch 13/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9996 - loss: 0.0060 - val_accuracy: 0.9378 - val_loss: 0.2347
# Epoch 14/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9997 - loss: 0.0051 - val_accuracy: 0.9374 - val_loss: 0.2419
# Epoch 15/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9997 - loss: 0.0044 - val_accuracy: 0.9364 - val_loss: 0.2501
# Epoch 16/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9997 - loss: 0.0037 - val_accuracy: 0.9360 - val_loss: 0.2572
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9998 - loss: 0.0031 - val_accuracy: 0.9356 - val_loss: 0.2667
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9998 - loss: 0.0026 - val_accuracy: 0.9356 - val_loss: 0.2727
# Epoch 19/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9999 - loss: 0.0022 - val_accuracy: 0.9358 - val_loss: 0.2794
# Epoch 20/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9354 - val_loss: 0.2860

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "r--", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("[IMDB] Training and validation loss")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "r--", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("[IMDB] Training and validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8008 - loss: 0.4860
# Epoch 2/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9117 - loss: 0.2460
# Epoch 3/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9385 - loss: 0.1788
# Epoch 4/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9519 - loss: 0.1423
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8759 - loss: 0.3225

# %%
results
# Out:
# [0.32248547673225403, 0.8759199976921082]

# %% [markdown]
# #### 훈련된 모델로 새로운 데이터에 대해 예측하기

# %%
model.predict(x_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[0.10418339],
#        [0.99946433],
#        [0.49317262],
#        ...,
#        [0.04745715],
#        [0.03121573],
#        [0.64436185]], dtype=float32)

# %% [markdown]
# #### 추가 실험

# %% [markdown]
# #### 정리

# %% [markdown]
# ### 뉴스 기사 분류: 다중 분류 문제

# %% [markdown]
# #### 로이터 데이터셋

# %%
from keras.datasets import reuters

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
    num_words=10000
)

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[10]]
)

# %%
train_labels[10]
# Out:
# np.int64(3)

# %% [markdown]
# #### 데이터 준비

# %%
x_train = multi_hot_encode(train_data, num_classes=10000)
x_test = multi_hot_encode(test_data, num_classes=10000)

# %%
def one_hot_encode(labels, num_classes=46):
    results = np.zeros((len(labels), num_classes))
    for i, label in enumerate(labels):
        results[i, label] = 1.0
    return results

y_train = one_hot_encode(train_labels)
y_test = one_hot_encode(test_labels)

# %%
from keras.utils import to_categorical

y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# #### 모델 만들기

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)

# %%
top_3_accuracy = keras.metrics.TopKCategoricalAccuracy(
    k=3, name="top_3_accuracy"
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy", top_3_accuracy],
)

# %% [markdown]
# #### 훈련 및 검증

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %%
history = model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=512,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.4718 - loss: 3.3183 - top_3_accuracy: 0.6016 - val_accuracy: 0.5910 - val_loss: 2.5945 - val_top_3_accuracy: 0.7190
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6431 - loss: 2.0549 - top_3_accuracy: 0.7630 - val_accuracy: 0.6510 - val_loss: 1.6918 - val_top_3_accuracy: 0.7680
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7166 - loss: 1.3616 - top_3_accuracy: 0.8244 - val_accuracy: 0.7140 - val_loss: 1.2881 - val_top_3_accuracy: 0.8210
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7779 - loss: 1.0213 - top_3_accuracy: 0.8786 - val_accuracy: 0.7600 - val_loss: 1.1093 - val_top_3_accuracy: 0.8600
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8329 - loss: 0.8015 - top_3_accuracy: 0.9139 - val_accuracy: 0.7890 - val_loss: 1.0166 - val_top_3_accuracy: 0.8870
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8713 - loss: 0.6334 - top_3_accuracy: 0.9439 - val_accuracy: 0.8050 - val_loss: 0.9473 - val_top_3_accuracy: 0.8980
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9000 - loss: 0.4965 - top_3_accuracy: 0.9632 - val_accuracy: 0.8150 - val_loss: 0.9011 - val_top_3_accuracy: 0.9140
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9197 - loss: 0.3963 - top_3_accuracy: 0.9767 - val_accuracy: 0.8150 - val_loss: 0.8822 - val_top_3_accuracy: 0.9180
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9347 - loss: 0.3151 - top_3_accuracy: 0.9867 - val_accuracy: 0.8170 - val_loss: 0.8708 - val_top_3_accuracy: 0.9230
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9422 - loss: 0.2580 - top_3_accuracy: 0.9914 - val_accuracy: 0.8210 - val_loss: 0.8673 - val_top_3_accuracy: 0.9230
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9484 - loss: 0.2205 - top_3_accuracy: 0.9939 - val_accuracy: 0.8150 - val_loss: 0.8677 - val_top_3_accuracy: 0.9290
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9513 - loss: 0.1872 - top_3_accuracy: 0.9955 - val_accuracy: 0.8090 - val_loss: 0.8866 - val_top_3_accuracy: 0.9280
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9554 - loss: 0.1676 - top_3_accuracy: 0.9965 - val_accuracy: 0.8110 - val_loss: 0.8859 - val_top_3_accuracy: 0.9260
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9550 - loss: 0.1534 - top_3_accuracy: 0.9975 - val_accuracy: 0.8150 - val_loss: 0.9137 - val_top_3_accuracy: 0.9250
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9583 - loss: 0.1368 - top_3_accuracy: 0.9980 - val_accuracy: 0.8150 - val_loss: 0.9232 - val_top_3_accuracy: 0.9270
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9603 - loss: 0.1275 - top_3_accuracy: 0.9980 - val_accuracy: 0.8100 - val_loss: 0.9246 - val_top_3_accuracy: 0.9330
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9589 - loss: 0.1181 - top_3_accuracy: 0.9984 - val_accuracy: 0.8140 - val_loss: 0.9359 - val_top_3_accuracy: 0.9320
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9604 - loss: 0.1128 - top_3_accuracy: 0.9984 - val_accuracy: 0.8140 - val_loss: 0.9397 - val_top_3_accuracy: 0.9260
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9609 - loss: 0.1059 - top_3_accuracy: 0.9989 - val_accuracy: 0.8050 - val_loss: 0.9651 - val_top_3_accuracy: 0.9290
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9620 - loss: 0.1051 - top_3_accuracy: 0.9984 - val_accuracy: 0.8130 - val_loss: 0.9641 - val_top_3_accuracy: 0.9300

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["top_3_accuracy"]
val_acc = history.history["val_top_3_accuracy"]
plt.plot(epochs, acc, "r--", label="Training top-3 accuracy")
plt.plot(epochs, val_acc, "b", label="Validation top-3 accuracy")
plt.title("Training and validation top-3 accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Top-3 accuracy")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    x_train,
    y_train,
    epochs=9,
    batch_size=512,
)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.4552 - loss: 3.2657
# Epoch 2/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6303 - loss: 1.8906
# Epoch 3/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7344 - loss: 1.2396
# Epoch 4/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7999 - loss: 0.9446
# Epoch 5/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8473 - loss: 0.7363
# Epoch 6/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8843 - loss: 0.5691
# Epoch 7/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9096 - loss: 0.4442
# Epoch 8/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9271 - loss: 0.3506
# Epoch 9/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9389 - loss: 0.2786
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7921 - loss: 0.9424

# %%
results
# Out:
# [0.9423995614051819, 0.7920747995376587]

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels == test_labels_copy)
hits_array.mean()
# Out:
# np.float64(0.18699910952804988)

# %% [markdown]
# #### 새로운 데이터에 대해 예측하기

# %%
predictions = model.predict(x_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# np.float32(1.0)

# %%
np.argmax(predictions[0])
# Out:
# np.int64(3)

# %% [markdown]
# #### 레이블과 손실을 다루는 다른 방법

# %%
y_train = train_labels
y_test = test_labels

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %% [markdown]
# #### 중간층을 충분히 크게 만들어야 하는 이유

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(4, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=128,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.1264 - loss: 3.7744 - val_accuracy: 0.0330 - val_loss: 3.6675
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1392 - loss: 3.3354 - val_accuracy: 0.3950 - val_loss: 2.8275
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4055 - loss: 2.2811 - val_accuracy: 0.4040 - val_loss: 2.0747
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5744 - loss: 1.6683 - val_accuracy: 0.6040 - val_loss: 1.6612
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6230 - loss: 1.4577 - val_accuracy: 0.6000 - val_loss: 1.6254
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6527 - loss: 1.3104 - val_accuracy: 0.6470 - val_loss: 1.5137
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7228 - loss: 1.1236 - val_accuracy: 0.6690 - val_loss: 1.4631
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7440 - loss: 1.0073 - val_accuracy: 0.6690 - val_loss: 1.4764
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7570 - loss: 0.9339 - val_accuracy: 0.6780 - val_loss: 1.4829
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7647 - loss: 0.8725 - val_accuracy: 0.6750 - val_loss: 1.5129
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7679 - loss: 0.8262 - val_accuracy: 0.6760 - val_loss: 1.5247
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7717 - loss: 0.7839 - val_accuracy: 0.6840 - val_loss: 1.5911
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7752 - loss: 0.7498 - val_accuracy: 0.6790 - val_loss: 1.6102
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7934 - loss: 0.7225 - val_accuracy: 0.6790 - val_loss: 1.6546
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7999 - loss: 0.6959 - val_accuracy: 0.6750 - val_loss: 1.6923
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8059 - loss: 0.6756 - val_accuracy: 0.6710 - val_loss: 1.7317
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8076 - loss: 0.6581 - val_accuracy: 0.6760 - val_loss: 1.7999
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8087 - loss: 0.6404 - val_accuracy: 0.6760 - val_loss: 1.8141
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8086 - loss: 0.6232 - val_accuracy: 0.6670 - val_loss: 1.8898
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8112 - loss: 0.6113 - val_accuracy: 0.6710 - val_loss: 1.9291

# %% [markdown]
# #### 추가 실험

# %% [markdown]
# #### 정리

# %% [markdown]
# ### 주택 가격 예측: 회귀 문제

# %% [markdown]
# #### 캘리포니아 주택 가격 데이터셋

# %%
from keras.datasets import california_housing

(train_data, train_targets), (test_data, test_targets) = (
    california_housing.load_data(version="small")
)

# %%
train_data.shape
# Out:
# (480, 8)

# %%
test_data.shape
# Out:
# (120, 8)

# %%
train_targets
# Out:
# array([228400., 132900.,  60000.,  95200., 107000., 122500., 132000.,
#        290100., 257800., 390100., 220800., 284900.,  97500., 415300.,
#         84200., 185600., 216700., 233100., 127000., 182300.,  92300.,
#         90700., 102100., 112500., 350700., 156500., 220700., 147400.,
#        216700., 275000., 198200., 119100., 289500., 152500., 125000.,
#        104500.,  93800.,  89300., 452600., 128600., 311500.,  90000.,
#        218200., 131300.,  67500., 139400., 500001., 182600., 111300.,
#        112500., 134700.,  71300., 207400., 331400., 107900.,  87500.,
#        342200.,  87100., 314700., 368600., 211600., 338900., 366100.,
#        164300.,  91700., 261400., 218500., 155400., 273700.,  81800.,
#        138800.,  99700., 156300., 140600., 152700., 108900., 351200.,
#        126000., 137500., 196900., 240000., 172800., 254200.,  97500.,
#        182700., 162500.,  86100., 226700., 412500., 165900., 327100.,
#        162500., 188800., 183800.,  90600., 372000., 275000., 151800.,
#        125000., 129100., 176000., 124700., 215300., 198100., 206300.,
#        122300., 277800., 335200., 274700., 132600., 143900., 299200.,
#        160000., 210200., 171400., 138800., 203300., 143800.,  85800.,
#         75000., 112200., 340400., 105500., 208100., 270900.,  85700.,
#         81300., 352100., 285800., 270600., 216700., 270100., 374400.,
#        192100., 241700., 341300., 150000., 126300., 118800., 500001.,
#         95200., 173700., 175000., 113900., 335000., 100000., 235600.,
#        109700., 210200.,  81400., 286600., 201300., 142300., 102300.,
#        184400.,  98300., 295200., 247100., 107500., 104900.,  79700.,
#        112500., 318200.,  83400., 269500., 227900., 287500., 261100.,
#        166900., 144000., 245500., 101600., 471600., 240700., 137500.,
#         75000.,  80800., 257300., 162900., 292000., 323500., 126900.,
#        351800., 269700., 212900., 259600., 268500., 182300., 197900.,
#        213500., 107600., 231600., 335300., 257400., 100000., 206200.,
#        119400., 118100.,  92500., 158700., 289900., 101400., 125000.,
#         91400., 500001., 500001., 275700., 457800., 239800., 250000.,
#        191700., 130000., 156900., 118800.,  88800., 153100., 231000.,
#        430500., 333300., 141900., 140000., 209400., 270900., 225000.,
#        229100., 150000., 164700.,  82800., 135800., 116700., 405400.,
#        231600.,  89500., 276800., 248600., 195800.,  98200., 319300.,
#        241700., 229800., 306300., 118000., 227700., 128800., 344000.,
#        120000., 110400., 335600., 109400., 161900., 135300., 142500.,
#        347600., 391800.,  82400., 332500., 336800., 109500., 391100.,
#         84700., 252900., 200000., 164300., 187500., 392600., 417500.,
#        263400., 313400., 115400.,  76100., 253600., 265400., 218800.,
#        116100., 169300., 114800., 358800., 302100., 143800., 446200.,
#        456300., 293000., 142600., 137500., 157300., 229300., 102200.,
#        169900., 243100.,  86500., 111100., 246200., 208800., 248500.,
#        295200., 500001., 164400., 365900., 296400., 376900., 242800.,
#         91800., 129500., 130600., 220900., 250000., 263900.,  72500.,
#        234100., 144800., 150000.,  70000.,  90500., 105500., 218400.,
#        282100., 147500., 224200., 120100., 104200.,  97200., 112500.,
#         94800., 273000., 159800., 225000.,  96200., 327600., 111900.,
#        266700., 333000., 375400., 350000., 103900., 243800.,  87100.,
#        141700., 366700.,  80000., 174200., 106300., 102000.,  88900.,
#        348700., 132500., 272900., 292300., 231800., 162500., 187500.,
#        352400., 384600., 153600., 240900., 500001., 189600., 151000.,
#        163500., 229200.,  98700., 138800., 136700., 398600., 254900.,
#        137000., 146900., 371300., 220800., 346800., 341600., 199600.,
#        140600., 342200., 137500., 411500., 125000.,  72000.,  83500.,
#        357300., 187500., 410300., 112500., 273800., 179300., 143400.,
#        121600., 177500., 252800., 287500., 271400., 121400., 131900.,
#        329800.,  85000., 127900., 155500., 172700., 113300., 125000.,
#        252500., 102400., 136700., 221300., 191400.,  82000., 218500.,
#        227000., 144800., 500001., 232500., 243400., 259400., 137500.,
#        337300., 179200., 102800., 207900., 362900., 350000.,  73500.,
#        371100., 182700., 389500., 140600.,  87500., 142900., 196400.,
#        126600., 123500., 311100., 159200.,  95000.,  81800., 253500.,
#        215700., 171900.,  85300.,  80600.,  89300.,  84400.,  75000.,
#        228100.,  95500., 187100.,  94800., 224100., 239600., 115000.,
#        353900., 256100., 335700., 291700., 206300., 119400., 350000.,
#        287300., 191300.,  93800., 175000., 500001., 179300., 118800.,
#        206800., 179900.,  80300., 195500., 147900., 483300., 268800.,
#        158400.,  94300.,  97300., 275400., 248900., 273400., 259300.,
#         75700., 336700., 140500., 217100.], dtype=float32)

# %% [markdown]
# #### 데이터 준비

# %%
mean = train_data.mean(axis=0)
std = train_data.std(axis=0)
x_train = (train_data - mean) / std
x_test = (test_data - mean) / std

# %%
y_train = train_targets / 100000
y_test = test_targets / 100000

# %% [markdown]
# #### 모델 만들기

# %%
def get_model():
    model = keras.Sequential(
        [
            layers.Dense(64, activation="relu"),
            layers.Dense(64, activation="relu"),
            layers.Dense(1),
        ]
    )
    model.compile(
        optimizer="adam",
        loss="mean_squared_error",
        metrics=["mean_absolute_error"],
    )
    return model

# %% [markdown]
# #### 훈련 및 K-겹 교차 검증

# %%
k = 4
num_val_samples = len(x_train) // k
num_epochs = 50
all_scores = []
for i in range(k):
    print(f"#{i + 1}번째 폴드 처리 중")
    fold_x_val = x_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_y_val = y_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_x_train = np.concatenate(
        [x_train[: i * num_val_samples], x_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    fold_y_train = np.concatenate(
        [y_train[: i * num_val_samples], y_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    model = get_model()
    model.fit(
        fold_x_train,
        fold_y_train,
        epochs=num_epochs,
        batch_size=16,
        verbose=0,
    )
    scores = model.evaluate(fold_x_val, fold_y_val, verbose=0)
    val_loss, val_mae = scores
    all_scores.append(val_mae)
# Out:
# #1번째 폴드 처리 중
# #2번째 폴드 처리 중
# #3번째 폴드 처리 중
# #4번째 폴드 처리 중

# %%
[round(value, 3) for value in all_scores]
# Out:
# [0.284, 0.278, 0.272, 0.313]

# %%
round(np.mean(all_scores), 3)
# Out:
# np.float64(0.287)

# %%
k = 4
num_val_samples = len(x_train) // k
num_epochs = 200
all_mae_histories = []
for i in range(k):
    print(f"#{i + 1}번째 폴드 처리 중")
    fold_x_val = x_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_y_val = y_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_x_train = np.concatenate(
        [x_train[: i * num_val_samples], x_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    fold_y_train = np.concatenate(
        [y_train[: i * num_val_samples], y_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    model = get_model()
    history = model.fit(
        fold_x_train,
        fold_y_train,
        validation_data=(fold_x_val, fold_y_val),
        epochs=num_epochs,
        batch_size=16,
        verbose=0,
    )
    mae_history = history.history["val_mean_absolute_error"]
    all_mae_histories.append(mae_history)
# Out:
# #1번째 폴드 처리 중
# #2번째 폴드 처리 중
# #3번째 폴드 처리 중
# #4번째 폴드 처리 중

# %%
average_mae_history = [
    np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)
]

# %%
epochs = range(1, len(average_mae_history) + 1)
plt.plot(epochs, average_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %%
truncated_mae_history = average_mae_history[10:]
epochs = range(10, len(truncated_mae_history) + 10)
plt.plot(epochs, truncated_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %%
model = get_model()
model.fit(x_train, y_train, epochs=130, batch_size=16, verbose=0)
test_mean_squared_error, test_mean_absolute_error = model.evaluate(
    x_test, y_test
)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.2953 - mean_absolute_error: 0.3145

# %%
round(test_mean_absolute_error, 3)
# Out:
# 0.314

# %% [markdown]
# #### 새로운 데이터에 대해 예측하기

# %%
predictions = model.predict(x_test)
predictions[0]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# array([2.3848324], dtype=float32)

# %% [markdown]
# #### 정리
